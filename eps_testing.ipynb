# %% [markdown]
# ### 暫時看新聞用
# 過濾掉 EPS < 1 和 YoY < 10% 的標的

# %%
from finlab import data
from finlab.dataframe import FinlabDataFrame
import pandas as pd
from datetime import datetime
import os

# 參數設定
length = 24
std_dev = 1
required_follow_up = 5
must_fulfill_full_count = False  # True 時強制要有滿足的後續根數才能通過
eps_level = 1
yoy_level = 5 # 10 means 10%

data.force_cloud_download = False
data.truncate_start = '2024-09-01'
# data.truncate_end = '2025-05-13'

long_result = []

def save_daily_list_pd(data, common_int_sorted, filename="daily_list.csv"):
    today = data.index[-1].strftime('%Y-%m-%d')
    weekday = datetime.now().strftime("%A")   # Monday, Tuesday...

    # 新的一筆資料
    df_new = pd.DataFrame({
        "date": [today],
        "weekday": [weekday],
        "values": [common_int_sorted]
    })
    
    # 若 CSV 不存在 → 直接建立
    if not os.path.exists(filename):
        df_new.to_csv(filename, index=False)
        return
    
    # 若 CSV 存在 → 先讀出
    df = pd.read_csv(filename)

    # 將 values 從字串轉回 list（避免重複 encoding）
    try:
        df["values"] = df["values"].apply(lambda x: ast.literal_eval(x))
    except:
        pass

    # 刪除今天舊資料
    df = df[df["date"] != today]
    
    # 加入今天新的
    df = pd.concat([df, df_new], ignore_index=True)
    
    # 儲存
    df.to_csv(filename, index=False)

# 限定只抓取上市櫃普通股 (排除ETF、ETN、特別股、存託憑證) 的股價。
with data.universe(market='TSE_OTC'):
    open_prices_all = data.get('price:開盤價')
    high_prices_all = data.get('price:最高價')
    low_prices_all = data.get('price:最低價')
    close_prices_all = data.get('price:收盤價')
    eps = data.get('financial_statement:每股盈餘') # 取得 EPS DataFrame
    rev_year_growth = data.get('monthly_revenue:去年同月增減(%)')
last_eps = eps.ffill().iloc[-1]  # 先 forward fill，然後取最後一列（最近的有效日期）
last_yoy = rev_year_growth.ffill().iloc[-1]

symbols_list = list(open_prices_all.columns)

for index, symbol in enumerate(symbols_list):

    # # 跳過不處理 symbol 不在 last_eps 裡面的資料
    # if symbol not in last_eps:
    #     print(f'第{index}個標的 - {symbol} ⚠️ 無 EPS 資料，跳過')
    #     continue

    # # 跳過 EPS < 0 的標的
    # if last_eps[symbol] < eps_level:
    #     print(f'第{index}個標的 - {symbol} ⚠️ EPS < 1，跳過')
    #     continue

    # 跳過不處理 symbol 不在 last_yoy 裡面的資料
    if symbol not in last_yoy:
        print(f'第{index}個標的 - {symbol} ⚠️ 無 YoY 資料，跳過')
        continue

    if last_yoy[symbol] < yoy_level:
        print(f'第{index}個標的 - {symbol} ⚠️ YoY < 10%，跳過')
        continue
        
    print(f'第{index}個標的 - {symbol}')
    
    open_prices = open_prices_all[[symbol]].tail(28)
    high_prices = high_prices_all[[symbol]].tail(28)
    low_prices = low_prices_all[[symbol]].tail(28)
    close_prices = close_prices_all[[symbol]].tail(28)

    #把開高低收合併成一個 Dataframe
    data = pd.DataFrame({
        'open': open_prices[symbol],
        'high': high_prices[symbol],
        'low': low_prices[symbol],
        'close': close_prices[symbol],
        'YoY': last_yoy[symbol],
        # 'eps': last_eps[symbol]
    }, index=open_prices.index )
    
    if data.shape[0] < 4:
        print(f"{symbol} 的資料筆數不足 4 筆，跳過該標的分析")
        continue

    data['MA'] = data['close'].rolling(window=length).mean()  # 移動平均線
    data['STD'] = data['close'].rolling(window=length).std(ddof=0)

    data['Upper_Band'] = data['MA'] + std_dev * data['STD']   # 上軌
    data['Lower_Band'] = data['MA'] - std_dev * data['STD']   # 下軌

    # 檢查是否符合突破條件 + 後續K棒站穩條件
    for x in range(-5, 0):  # 檢查最近5根
        try:
            prev_open = data.loc[data.index[x - 1], 'open']
            prev_close = data.loc[data.index[x - 1], 'close']
            prev_middle = (prev_open + prev_close) / 2
            prev_upper = data.loc[data.index[x - 1], 'Upper_Band']

            curr_open = data.loc[data.index[x], 'open']
            curr_close = data.loc[data.index[x], 'close']
            curr_middle = (curr_open + curr_close) / 2
            curr_upper = data.loc[data.index[x], 'Upper_Band']
        except:
            continue

        # 條件 1：前一根在上軌下方
        if prev_open < prev_upper and prev_middle < prev_upper:

            # 條件 2：當根突破布林上軌
            if (curr_open < curr_close and curr_middle >= curr_upper) or \
               (curr_open > curr_upper and curr_close > curr_upper):

                # 檢查後續K棒條件
                remaining_kbars = abs(x) - 1
                if must_fulfill_full_count and remaining_kbars < required_follow_up:
                    print(f'{symbol} - 不足 {required_follow_up} 根後續K棒，略過（強制驗證開啟）')
                    continue

                actual_check_count = min(remaining_kbars, required_follow_up)

                if actual_check_count == 0:
                    print(f'✅ {symbol} - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅')
                    long_result.append(symbol)
                    break

                follow_through_ok = True
                for i in range(1, actual_check_count + 1):
                    next_open = data.loc[data.index[x + i], 'open']
                    next_close = data.loc[data.index[x + i], 'close']
                    next_upper = data.loc[data.index[x + i], 'Upper_Band']

                    if next_open <= next_upper or next_close <= next_upper:
                        follow_through_ok = False
                        print(f"❌ {symbol} - 第{x + i}根不符合，open 或 close 未高於上軌 ❌")
                        break

                if follow_through_ok:
                    print(f'✅ {symbol} - 符合條件（突破 + 後續 {actual_check_count} 根站上），加入 long_result ✅')
                    long_result.append(symbol)
                    break

# 把結果拿去比對股票期貨的標的，有重複的在產出。
stockinfo = pd.read_excel("2_stockinfo.ods", engine="odf")
stockinfo_list = stockinfo['Unnamed: 2'].astype(str).tolist()

common = list(set(long_result) & set(stockinfo_list))

# 轉成 int 並排序
common_int_sorted = sorted(map(int, common))
long_result = sorted(map(int, set(long_result)))
save_daily_list_pd(data, common_int_sorted)

print('-----------------------------------')
print(data)
print()
print(f"一般 List: {long_result}\n")
print(f"股期 List: {common_int_sorted}")
# Out:
# 第0個標的 - 1101 ⚠️ YoY < 10%，跳過
# 第1個標的 - 1102 ⚠️ YoY < 10%，跳過
# 第2個標的 - 1103 ⚠️ YoY < 10%，跳過
# 第3個標的 - 1104 ⚠️ YoY < 10%，跳過
# 第4個標的 - 1107
# 第5個標的 - 1108 ⚠️ YoY < 10%，跳過
# 第6個標的 - 1109 ⚠️ YoY < 10%，跳過
# 第7個標的 - 1110 ⚠️ YoY < 10%，跳過
# 第8個標的 - 1201 ⚠️ YoY < 10%，跳過
# 第9個標的 - 1203 ⚠️ YoY < 10%，跳過
# 第10個標的 - 1210 ⚠️ YoY < 10%，跳過
# 第11個標的 - 1213
# 第12個標的 - 1215
# 第13個標的 - 1216 ⚠️ YoY < 10%，跳過
# 第14個標的 - 1217 ⚠️ YoY < 10%，跳過
# 第15個標的 - 1218
# 第16個標的 - 1219
# 第17個標的 - 1220 ⚠️ YoY < 10%，跳過
# 第18個標的 - 1225 ⚠️ YoY < 10%，跳過
# 第19個標的 - 1227 ⚠️ YoY < 10%，跳過
# 第20個標的 - 1229
# 第21個標的 - 1231 ⚠️ YoY < 10%，跳過
# 第22個標的 - 1232 ⚠️ YoY < 10%，跳過
# 第23個標的 - 1233 ⚠️ YoY < 10%，跳過
# 第24個標的 - 1234 ⚠️ YoY < 10%，跳過
# 第25個標的 - 1235 ⚠️ YoY < 10%，跳過
# 第26個標的 - 1236 ⚠️ YoY < 10%，跳過
# 第27個標的 - 1240 ⚠️ YoY < 10%，跳過
# 第28個標的 - 1256
# 第29個標的 - 1258
# 第30個標的 - 1259 ⚠️ YoY < 10%，跳過
# 第31個標的 - 1262
# 第32個標的 - 1264 ⚠️ YoY < 10%，跳過
# 第33個標的 - 1268 ⚠️ YoY < 10%，跳過
# 第34個標的 - 1294
# 第35個標的 - 1295
# 第36個標的 - 1301 ⚠️ YoY < 10%，跳過
# 第37個標的 - 1303 ⚠️ YoY < 10%，跳過
# 第38個標的 - 1304 ⚠️ YoY < 10%，跳過
# 第39個標的 - 1305 ⚠️ YoY < 10%，跳過
# 第40個標的 - 1307 ⚠️ YoY < 10%，跳過
# 第41個標的 - 1308 ⚠️ YoY < 10%，跳過
# 第42個標的 - 1309 ⚠️ YoY < 10%，跳過
# 第43個標的 - 1310 ⚠️ YoY < 10%，跳過
# 第44個標的 - 1311
# 第45個標的 - 1312
# ✅ 1312 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第46個標的 - 1313 ⚠️ YoY < 10%，跳過
# 第47個標的 - 1314 ⚠️ YoY < 10%，跳過
# 第48個標的 - 1315 ⚠️ YoY < 10%，跳過
# 第49個標的 - 1316
# 第50個標的 - 1319 ⚠️ YoY < 10%，跳過
# 第51個標的 - 1321 ⚠️ YoY < 10%，跳過
# 第52個標的 - 1323 ⚠️ YoY < 10%，跳過
# 第53個標的 - 1324 ⚠️ YoY < 10%，跳過
# 第54個標的 - 1325 ⚠️ YoY < 10%，跳過
# 第55個標的 - 1326 ⚠️ YoY < 10%，跳過
# 第56個標的 - 1333
# 第57個標的 - 1336 ⚠️ YoY < 10%，跳過
# 第58個標的 - 1337 ⚠️ YoY < 10%，跳過
# 第59個標的 - 1338 ⚠️ YoY < 10%，跳過
# 第60個標的 - 1339 ⚠️ YoY < 10%，跳過
# 第61個標的 - 1340 ⚠️ YoY < 10%，跳過
# 第62個標的 - 1341 ⚠️ YoY < 10%，跳過
# 第63個標的 - 1342
# ✅ 1342 - 符合條件（突破 + 後續 3 根站上），加入 long_result ✅
# 第64個標的 - 1402 ⚠️ YoY < 10%，跳過
# 第65個標的 - 1408
# 第66個標的 - 1409 ⚠️ YoY < 10%，跳過
# 第67個標的 - 1410 ⚠️ YoY < 10%，跳過
# 第68個標的 - 1413 ⚠️ YoY < 10%，跳過
# 第69個標的 - 1414 ⚠️ YoY < 10%，跳過
# 第70個標的 - 1416
# 第71個標的 - 1417 ⚠️ YoY < 10%，跳過
# 第72個標的 - 1418 ⚠️ YoY < 10%，跳過
# 第73個標的 - 1419 ⚠️ YoY < 10%，跳過
# 第74個標的 - 1423
# 第75個標的 - 1432
# 第76個標的 - 1434 ⚠️ YoY < 10%，跳過
# 第77個標的 - 1435 ⚠️ YoY < 10%，跳過
# 第78個標的 - 1436
# 第79個標的 - 1437 ⚠️ YoY < 10%，跳過
# 第80個標的 - 1438 ⚠️ YoY < 10%，跳過
# 第81個標的 - 1439
# 第82個標的 - 1440 ⚠️ YoY < 10%，跳過
# 第83個標的 - 1441 ⚠️ YoY < 10%，跳過
# 第84個標的 - 1442
# 第85個標的 - 1443 ⚠️ YoY < 10%，跳過
# 第86個標的 - 1444 ⚠️ YoY < 10%，跳過
# 第87個標的 - 1445
# 第88個標的 - 1446 ⚠️ YoY < 10%，跳過
# 第89個標的 - 1447 ⚠️ YoY < 10%，跳過
# 第90個標的 - 1449
# 第91個標的 - 1451
# 第92個標的 - 1452 ⚠️ YoY < 10%，跳過
# 第93個標的 - 1453
# 第94個標的 - 1454 ⚠️ YoY < 10%，跳過
# 第95個標的 - 1455 ⚠️ YoY < 10%，跳過
# 第96個標的 - 1456 ⚠️ YoY < 10%，跳過
# 第97個標的 - 1457 ⚠️ YoY < 10%，跳過
# 第98個標的 - 1459 ⚠️ YoY < 10%，跳過
# 第99個標的 - 1460 ⚠️ YoY < 10%，跳過
# 第100個標的 - 1462
# 第101個標的 - 1463 ⚠️ YoY < 10%，跳過
# 第102個標的 - 1464 ⚠️ YoY < 10%，跳過
# 第103個標的 - 1465 ⚠️ YoY < 10%，跳過
# 第104個標的 - 1466 ⚠️ YoY < 10%，跳過
# 第105個標的 - 1467
# 第106個標的 - 1468 ⚠️ YoY < 10%，跳過
# 第107個標的 - 1469
# 第108個標的 - 1470
# 第109個標的 - 1471 ⚠️ YoY < 10%，跳過
# 第110個標的 - 1472
# 第111個標的 - 1473 ⚠️ YoY < 10%，跳過
# 第112個標的 - 1474 ⚠️ YoY < 10%，跳過
# 第113個標的 - 1475 ⚠️ YoY < 10%，跳過
# 第114個標的 - 1476 ⚠️ YoY < 10%，跳過
# 第115個標的 - 1477 ⚠️ YoY < 10%，跳過
# 第116個標的 - 1503 ⚠️ YoY < 10%，跳過
# 第117個標的 - 1504
# 第118個標的 - 1506 ⚠️ YoY < 10%，跳過
# 第119個標的 - 1507
# 第120個標的 - 1512
# 第121個標的 - 1513
# 第122個標的 - 1514
# 第123個標的 - 1515
# 第124個標的 - 1516 ⚠️ YoY < 10%，跳過
# 第125個標的 - 1517 ⚠️ YoY < 10%，跳過
# 第126個標的 - 1519
# 第127個標的 - 1520
# 第128個標的 - 1521
# 第129個標的 - 1522
# 第130個標的 - 1523
# 第131個標的 - 1524 ⚠️ YoY < 10%，跳過
# 第132個標的 - 1525 ⚠️ YoY < 10%，跳過
# 第133個標的 - 1526
# 第134個標的 - 1527 ⚠️ YoY < 10%，跳過
# 第135個標的 - 1528 ⚠️ YoY < 10%，跳過
# 第136個標的 - 1529
# 第137個標的 - 1530 ⚠️ YoY < 10%，跳過
# 第138個標的 - 1531 ⚠️ YoY < 10%，跳過
# 第139個標的 - 1532 ⚠️ YoY < 10%，跳過
# 第140個標的 - 1533 ⚠️ YoY < 10%，跳過
# 第141個標的 - 1535 ⚠️ YoY < 10%，跳過
# 第142個標的 - 1536
# 第143個標的 - 1537 ⚠️ YoY < 10%，跳過
# 第144個標的 - 1538 ⚠️ YoY < 10%，跳過
# 第145個標的 - 1539 ⚠️ YoY < 10%，跳過
# 第146個標的 - 1540
# 第147個標的 - 1541 ⚠️ YoY < 10%，跳過
# 第148個標的 - 1558 ⚠️ YoY < 10%，跳過
# 第149個標的 - 1560
# 第150個標的 - 1563 ⚠️ YoY < 10%，跳過
# 第151個標的 - 1565 ⚠️ YoY < 10%，跳過
# 第152個標的 - 1566
# 第153個標的 - 1568
# 第154個標的 - 1569 ⚠️ YoY < 10%，跳過
# 第155個標的 - 1570 ⚠️ YoY < 10%，跳過
# 第156個標的 - 1580 ⚠️ YoY < 10%，跳過
# 第157個標的 - 1582 ⚠️ YoY < 10%，跳過
# 第158個標的 - 1583 ⚠️ YoY < 10%，跳過
# 第159個標的 - 1584 ⚠️ YoY < 10%，跳過
# 第160個標的 - 1586 ⚠️ YoY < 10%，跳過
# 第161個標的 - 1587
# 第162個標的 - 1589 ⚠️ YoY < 10%，跳過
# 第163個標的 - 1590
# 第164個標的 - 1591 ⚠️ YoY < 10%，跳過
# 第165個標的 - 1592
# 第166個標的 - 1593
# 第167個標的 - 1595 ⚠️ YoY < 10%，跳過
# 第168個標的 - 1597
# ❌ 1597 - 第-2根不符合，open 或 close 未高於上軌 ❌
# 第169個標的 - 1598 ⚠️ YoY < 10%，跳過
# 第170個標的 - 1599 ⚠️ YoY < 10%，跳過
# 第171個標的 - 1601
# 第172個標的 - 1603
# ✅ 1603 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第173個標的 - 1604 ⚠️ YoY < 10%，跳過
# 第174個標的 - 1605
# 第175個標的 - 1606
# 第176個標的 - 1608 ⚠️ YoY < 10%，跳過
# 第177個標的 - 1609 ⚠️ YoY < 10%，跳過
# 第178個標的 - 1611 ⚠️ YoY < 10%，跳過
# 第179個標的 - 1612
# 第180個標的 - 1613
# 第181個標的 - 1614 ⚠️ YoY < 10%，跳過
# 第182個標的 - 1615 ⚠️ YoY < 10%，跳過
# 第183個標的 - 1616 ⚠️ YoY < 10%，跳過
# 第184個標的 - 1617 ⚠️ YoY < 10%，跳過
# 第185個標的 - 1618 ⚠️ YoY < 10%，跳過
# 第186個標的 - 1626
# 第187個標的 - 1701
# 第188個標的 - 1702 ⚠️ YoY < 10%，跳過
# 第189個標的 - 1704
# 第190個標的 - 1707 ⚠️ YoY < 10%，跳過
# 第191個標的 - 1708 ⚠️ YoY < 10%，跳過
# 第192個標的 - 1709 ⚠️ YoY < 10%，跳過
# 第193個標的 - 1710 ⚠️ YoY < 10%，跳過
# 第194個標的 - 1711 ⚠️ YoY < 10%，跳過
# 第195個標的 - 1712 ⚠️ YoY < 10%，跳過
# 第196個標的 - 1713 ⚠️ YoY < 10%，跳過
# 第197個標的 - 1714
# ✅ 1714 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第198個標的 - 1715
# 第199個標的 - 1716
# 第200個標的 - 1717 ⚠️ YoY < 10%，跳過
# 第201個標的 - 1718 ⚠️ YoY < 10%，跳過
# 第202個標的 - 1720 ⚠️ YoY < 10%，跳過
# 第203個標的 - 1721
# 第204個標的 - 1722 ⚠️ YoY < 10%，跳過
# 第205個標的 - 1723 ⚠️ YoY < 10%，跳過
# 第206個標的 - 1724
# 第207個標的 - 1725 ⚠️ YoY < 10%，跳過
# 第208個標的 - 1726 ⚠️ YoY < 10%，跳過
# 第209個標的 - 1727
# 第210個標的 - 1729
# 第211個標的 - 1730 ⚠️ YoY < 10%，跳過
# 第212個標的 - 1731
# ❌ 1731 - 第-2根不符合，open 或 close 未高於上軌 ❌
# 第213個標的 - 1732
# 第214個標的 - 1733 ⚠️ YoY < 10%，跳過
# 第215個標的 - 1734 ⚠️ YoY < 10%，跳過
# 第216個標的 - 1735 ⚠️ YoY < 10%，跳過
# 第217個標的 - 1736
# 第218個標的 - 1737
# 第219個標的 - 1742 ⚠️ YoY < 10%，跳過
# 第220個標的 - 1752 ⚠️ YoY < 10%，跳過
# 第221個標的 - 1760
# 第222個標的 - 1762 ⚠️ YoY < 10%，跳過
# 第223個標的 - 1773 ⚠️ YoY < 10%，跳過
# 第224個標的 - 1776 ⚠️ YoY < 10%，跳過
# 第225個標的 - 1777 ⚠️ YoY < 10%，跳過
# 第226個標的 - 1781 ⚠️ YoY < 10%，跳過
# 第227個標的 - 1783
# ✅ 1783 - 符合條件（突破 + 後續 3 根站上），加入 long_result ✅
# 第228個標的 - 1784
# 第229個標的 - 1785
# 第230個標的 - 1786 ⚠️ YoY < 10%，跳過
# 第231個標的 - 1787
# 第232個標的 - 1788
# ✅ 1788 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第233個標的 - 1789 ⚠️ YoY < 10%，跳過
# 第234個標的 - 1795 ⚠️ YoY < 10%，跳過
# 第235個標的 - 1796
# 第236個標的 - 1799 ⚠️ YoY < 10%，跳過
# 第237個標的 - 1802 ⚠️ YoY < 10%，跳過
# 第238個標的 - 1805 ⚠️ YoY < 10%，跳過
# 第239個標的 - 1806 ⚠️ YoY < 10%，跳過
# 第240個標的 - 1807
# 第241個標的 - 1808
# ✅ 1808 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第242個標的 - 1809 ⚠️ YoY < 10%，跳過
# 第243個標的 - 1810 ⚠️ YoY < 10%，跳過
# 第244個標的 - 1813 ⚠️ YoY < 10%，跳過
# 第245個標的 - 1815
# 第246個標的 - 1817 ⚠️ YoY < 10%，跳過
# 第247個標的 - 1902
# 第248個標的 - 1903 ⚠️ YoY < 10%，跳過
# 第249個標的 - 1904 ⚠️ YoY < 10%，跳過
# 第250個標的 - 1905 ⚠️ YoY < 10%，跳過
# 第251個標的 - 1906
# 第252個標的 - 1907 ⚠️ YoY < 10%，跳過
# 第253個標的 - 1909 ⚠️ YoY < 10%，跳過
# 第254個標的 - 2002 ⚠️ YoY < 10%，跳過
# 第255個標的 - 2006 ⚠️ YoY < 10%，跳過
# 第256個標的 - 2007 ⚠️ YoY < 10%，跳過
# 第257個標的 - 2008 ⚠️ YoY < 10%，跳過
# 第258個標的 - 2009 ⚠️ YoY < 10%，跳過
# 第259個標的 - 2010 ⚠️ YoY < 10%，跳過
# 第260個標的 - 2012 ⚠️ YoY < 10%，跳過
# 第261個標的 - 2013 ⚠️ YoY < 10%，跳過
# 第262個標的 - 2014 ⚠️ YoY < 10%，跳過
# 第263個標的 - 2015 ⚠️ YoY < 10%，跳過
# 第264個標的 - 2017 ⚠️ YoY < 10%，跳過
# 第265個標的 - 2020 ⚠️ YoY < 10%，跳過
# 第266個標的 - 2022
# ❌ 2022 - 第-1根不符合，open 或 close 未高於上軌 ❌
# 第267個標的 - 2023 ⚠️ YoY < 10%，跳過
# 第268個標的 - 2024 ⚠️ YoY < 10%，跳過
# 第269個標的 - 2025 ⚠️ YoY < 10%，跳過
# 第270個標的 - 2027
# 第271個標的 - 2028 ⚠️ YoY < 10%，跳過
# 第272個標的 - 2029 ⚠️ YoY < 10%，跳過
# 第273個標的 - 2030 ⚠️ YoY < 10%，跳過
# 第274個標的 - 2031 ⚠️ YoY < 10%，跳過
# 第275個標的 - 2032 ⚠️ YoY < 10%，跳過
# 第276個標的 - 2033
# 第277個標的 - 2034 ⚠️ YoY < 10%，跳過
# 第278個標的 - 2035 ⚠️ YoY < 10%，跳過
# 第279個標的 - 2038 ⚠️ YoY < 10%，跳過
# 第280個標的 - 2049
# 第281個標的 - 2059
# 第282個標的 - 2061 ⚠️ YoY < 10%，跳過
# 第283個標的 - 2062 ⚠️ YoY < 10%，跳過
# 第284個標的 - 2063 ⚠️ YoY < 10%，跳過
# 第285個標的 - 2064
# 第286個標的 - 2065
# ✅ 2065 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第287個標的 - 2066 ⚠️ YoY < 10%，跳過
# 第288個標的 - 2067 ⚠️ YoY < 10%，跳過
# 第289個標的 - 2069 ⚠️ YoY < 10%，跳過
# 第290個標的 - 2070
# 第291個標的 - 2073 ⚠️ YoY < 10%，跳過
# 第292個標的 - 2101 ⚠️ YoY < 10%，跳過
# 第293個標的 - 2102
# 第294個標的 - 2103 ⚠️ YoY < 10%，跳過
# 第295個標的 - 2104 ⚠️ YoY < 10%，跳過
# 第296個標的 - 2105 ⚠️ YoY < 10%，跳過
# 第297個標的 - 2106 ⚠️ YoY < 10%，跳過
# 第298個標的 - 2107 ⚠️ YoY < 10%，跳過
# 第299個標的 - 2108 ⚠️ YoY < 10%，跳過
# 第300個標的 - 2109 ⚠️ YoY < 10%，跳過
# 第301個標的 - 2114
# 第302個標的 - 2115 ⚠️ YoY < 10%，跳過
# 第303個標的 - 2201 ⚠️ YoY < 10%，跳過
# 第304個標的 - 2204
# 第305個標的 - 2206 ⚠️ YoY < 10%，跳過
# 第306個標的 - 2207 ⚠️ YoY < 10%，跳過
# 第307個標的 - 2208 ⚠️ YoY < 10%，跳過
# 第308個標的 - 2211 ⚠️ YoY < 10%，跳過
# 第309個標的 - 2221 ⚠️ YoY < 10%，跳過
# 第310個標的 - 2227 ⚠️ YoY < 10%，跳過
# 第311個標的 - 2228 ⚠️ YoY < 10%，跳過
# 第312個標的 - 2230 ⚠️ YoY < 10%，跳過
# 第313個標的 - 2231 ⚠️ YoY < 10%，跳過
# 第314個標的 - 2233 ⚠️ YoY < 10%，跳過
# 第315個標的 - 2235 ⚠️ YoY < 10%，跳過
# 第316個標的 - 2236
# 第317個標的 - 2239 ⚠️ YoY < 10%，跳過
# 第318個標的 - 2241
# 第319個標的 - 2243 ⚠️ YoY < 10%，跳過
# 第320個標的 - 2247 ⚠️ YoY < 10%，跳過
# 第321個標的 - 2248
# 第322個標的 - 2250 ⚠️ YoY < 10%，跳過
# 第323個標的 - 2254 ⚠️ YoY < 10%，跳過
# 第324個標的 - 2258 ⚠️ YoY < 10%，跳過
# 第325個標的 - 2301
# 第326個標的 - 2302
# 第327個標的 - 2303 ⚠️ YoY < 10%，跳過
# 第328個標的 - 2305
# ❌ 2305 - 第-1根不符合，open 或 close 未高於上軌 ❌
# 第329個標的 - 2308
# 第330個標的 - 2311
# 第331個標的 - 2312 ⚠️ YoY < 10%，跳過
# 第332個標的 - 2313
# ✅ 2313 - 符合條件（突破 + 後續 3 根站上），加入 long_result ✅
# 第333個標的 - 2314 ⚠️ YoY < 10%，跳過
# 第334個標的 - 2315
# 第335個標的 - 2316
# 第336個標的 - 2317
# 第337個標的 - 2321 ⚠️ YoY < 10%，跳過
# 第338個標的 - 2323 ⚠️ YoY < 10%，跳過
# 第339個標的 - 2324 ⚠️ YoY < 10%，跳過
# 第340個標的 - 2325
# 第341個標的 - 2326
# 第342個標的 - 2327
# 第343個標的 - 2328 ⚠️ YoY < 10%，跳過
# 第344個標的 - 2329
# 第345個標的 - 2330
# 第346個標的 - 2331
# 第347個標的 - 2332 ⚠️ YoY < 10%，跳過
# 第348個標的 - 2336
# 第349個標的 - 2337
# 第350個標的 - 2338 ⚠️ YoY < 10%，跳過
# 第351個標的 - 2340 ⚠️ YoY < 10%，跳過
# 第352個標的 - 2341
# 第353個標的 - 2342 ⚠️ YoY < 10%，跳過
# 第354個標的 - 2344
# 第355個標的 - 2345
# 第356個標的 - 2347
# ✅ 2347 - 符合條件（突破 + 後續 2 根站上），加入 long_result ✅
# 第357個標的 - 2348
# 第358個標的 - 2349 ⚠️ YoY < 10%，跳過
# 第359個標的 - 2350
# 第360個標的 - 2351 ⚠️ YoY < 10%，跳過
# 第361個標的 - 2352 ⚠️ YoY < 10%，跳過
# 第362個標的 - 2353
# 第363個標的 - 2354 ⚠️ YoY < 10%，跳過
# 第364個標的 - 2355
# 第365個標的 - 2356 ⚠️ YoY < 10%，跳過
# 第366個標的 - 2357
# 第367個標的 - 2358 ⚠️ YoY < 10%，跳過
# 第368個標的 - 2359
# ❌ 2359 - 第-3根不符合，open 或 close 未高於上軌 ❌
# 第369個標的 - 2360
# 第370個標的 - 2361
# 第371個標的 - 2362 ⚠️ YoY < 10%，跳過
# 第372個標的 - 2363
# 第373個標的 - 2364 ⚠️ YoY < 10%，跳過
# 第374個標的 - 2365
# 第375個標的 - 2367 ⚠️ YoY < 10%，跳過
# 第376個標的 - 2368
# 第377個標的 - 2369
# ✅ 2369 - 符合條件（突破 + 後續 2 根站上），加入 long_result ✅
# 第378個標的 - 2371
# 第379個標的 - 2373 ⚠️ YoY < 10%，跳過
# 第380個標的 - 2374
# 第381個標的 - 2375
# 第382個標的 - 2376
# 第383個標的 - 2377
# 第384個標的 - 2379 ⚠️ YoY < 10%，跳過
# 第385個標的 - 2380
# ✅ 2380 - 符合條件（突破 + 後續 2 根站上），加入 long_result ✅
# 第386個標的 - 2381
# 第387個標的 - 2382
# 第388個標的 - 2383
# ❌ 2383 - 第-3根不符合，open 或 close 未高於上軌 ❌
# 第389個標的 - 2384
# 第390個標的 - 2385 ⚠️ YoY < 10%，跳過
# 第391個標的 - 2387 ⚠️ YoY < 10%，跳過
# 第392個標的 - 2388 ⚠️ YoY < 10%，跳過
# 第393個標的 - 2390 ⚠️ YoY < 10%，跳過
# 第394個標的 - 2391
# 第395個標的 - 2392 ⚠️ YoY < 10%，跳過
# 第396個標的 - 2393 ⚠️ YoY < 10%，跳過
# 第397個標的 - 2395
# 第398個標的 - 2396
# 第399個標的 - 2397 ⚠️ YoY < 10%，跳過
# 第400個標的 - 2399
# 第401個標的 - 2401 ⚠️ YoY < 10%，跳過
# 第402個標的 - 2402
# 第403個標的 - 2403
# 第404個標的 - 2404
# 第405個標的 - 2405
# 第406個標的 - 2406
# 第407個標的 - 2408
# 第408個標的 - 2409 ⚠️ YoY < 10%，跳過
# 第409個標的 - 2410
# 第410個標的 - 2411
# 第411個標的 - 2412
# 第412個標的 - 2413 ⚠️ YoY < 10%，跳過
# 第413個標的 - 2414
# 第414個標的 - 2415
# ✅ 2415 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第415個標的 - 2417
# 第416個標的 - 2418
# 第417個標的 - 2419
# ✅ 2419 - 符合條件（突破 + 後續 3 根站上），加入 long_result ✅
# 第418個標的 - 2420 ⚠️ YoY < 10%，跳過
# 第419個標的 - 2421
# 第420個標的 - 2423 ⚠️ YoY < 10%，跳過
# 第421個標的 - 2424 ⚠️ YoY < 10%，跳過
# 第422個標的 - 2425
# 第423個標的 - 2426 ⚠️ YoY < 10%，跳過
# 第424個標的 - 2427 ⚠️ YoY < 10%，跳過
# 第425個標的 - 2428 ⚠️ YoY < 10%，跳過
# 第426個標的 - 2429
# 第427個標的 - 2430 ⚠️ YoY < 10%，跳過
# 第428個標的 - 2431 ⚠️ YoY < 10%，跳過
# 第429個標的 - 2432
# 第430個標的 - 2433 ⚠️ YoY < 10%，跳過
# 第431個標的 - 2434 ⚠️ YoY < 10%，跳過
# 第432個標的 - 2436
# ❌ 2436 - 第-2根不符合，open 或 close 未高於上軌 ❌
# 第433個標的 - 2437
# 第434個標的 - 2438 ⚠️ YoY < 10%，跳過
# 第435個標的 - 2439
# ✅ 2439 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第436個標的 - 2440 ⚠️ YoY < 10%，跳過
# 第437個標的 - 2441 ⚠️ YoY < 10%，跳過
# 第438個標的 - 2442
# 第439個標的 - 2443
# 第440個標的 - 2444
# 第441個標的 - 2446
# 第442個標的 - 2447
# 第443個標的 - 2448
# 第444個標的 - 2449
# 第445個標的 - 2450
# 第446個標的 - 2451
# 第447個標的 - 2452
# 第448個標的 - 2453
# 第449個標的 - 2454
# 第450個標的 - 2455
# ❌ 2455 - 第-2根不符合，open 或 close 未高於上軌 ❌
# 第451個標的 - 2456
# 第452個標的 - 2457 ⚠️ YoY < 10%，跳過
# 第453個標的 - 2458 ⚠️ YoY < 10%，跳過
# 第454個標的 - 2459
# 第455個標的 - 2460
# 第456個標的 - 2461 ⚠️ YoY < 10%，跳過
# 第457個標的 - 2462 ⚠️ YoY < 10%，跳過
# 第458個標的 - 2463
# 第459個標的 - 2464 ⚠️ YoY < 10%，跳過
# 第460個標的 - 2465 ⚠️ YoY < 10%，跳過
# 第461個標的 - 2466 ⚠️ YoY < 10%，跳過
# 第462個標的 - 2467
# 第463個標的 - 2468 ⚠️ YoY < 10%，跳過
# 第464個標的 - 2469
# 第465個標的 - 2471
# 第466個標的 - 2472
# 第467個標的 - 2473
# 第468個標的 - 2474 ⚠️ YoY < 10%，跳過
# 第469個標的 - 2475
# 第470個標的 - 2476
# 第471個標的 - 2477
# ✅ 2477 - 符合條件（突破 + 後續 3 根站上），加入 long_result ✅
# 第472個標的 - 2478 ⚠️ YoY < 10%，跳過
# 第473個標的 - 2479
# 第474個標的 - 2480 ⚠️ YoY < 10%，跳過
# 第475個標的 - 2481
# 第476個標的 - 2482 ⚠️ YoY < 10%，跳過
# 第477個標的 - 2483 ⚠️ YoY < 10%，跳過
# 第478個標的 - 2484 ⚠️ YoY < 10%，跳過
# 第479個標的 - 2485
# 第480個標的 - 2486
# 第481個標的 - 2488 ⚠️ YoY < 10%，跳過
# 第482個標的 - 2489 ⚠️ YoY < 10%，跳過
# 第483個標的 - 2491 ⚠️ YoY < 10%，跳過
# 第484個標的 - 2492
# 第485個標的 - 2493
# 第486個標的 - 2494
# 第487個標的 - 2495 ⚠️ YoY < 10%，跳過
# 第488個標的 - 2496
# 第489個標的 - 2497 ⚠️ YoY < 10%，跳過
# 第490個標的 - 2498 ⚠️ YoY < 10%，跳過
# 第491個標的 - 2499
# 第492個標的 - 2501 ⚠️ YoY < 10%，跳過
# 第493個標的 - 2504 ⚠️ YoY < 10%，跳過
# 第494個標的 - 2505
# 第495個標的 - 2506
# 第496個標的 - 2509 ⚠️ YoY < 10%，跳過
# 第497個標的 - 2511
# ✅ 2511 - 符合條件（突破 + 後續 2 根站上），加入 long_result ✅
# 第498個標的 - 2514
# 第499個標的 - 2515 ⚠️ YoY < 10%，跳過
# 第500個標的 - 2516 ⚠️ YoY < 10%，跳過
# 第501個標的 - 2520
# 第502個標的 - 2524 ⚠️ YoY < 10%，跳過
# 第503個標的 - 2526
# 第504個標的 - 2527 ⚠️ YoY < 10%，跳過
# 第505個標的 - 2528 ⚠️ YoY < 10%，跳過
# 第506個標的 - 2530 ⚠️ YoY < 10%，跳過
# 第507個標的 - 2534 ⚠️ YoY < 10%，跳過
# 第508個標的 - 2535
# ✅ 2535 - 符合條件（突破 + 後續 3 根站上），加入 long_result ✅
# 第509個標的 - 2536 ⚠️ YoY < 10%，跳過
# 第510個標的 - 2537
# 第511個標的 - 2538 ⚠️ YoY < 10%，跳過
# 第512個標的 - 2539
# 第513個標的 - 2540 ⚠️ YoY < 10%，跳過
# 第514個標的 - 2542
# 第515個標的 - 2543
# 第516個標的 - 2545 ⚠️ YoY < 10%，跳過
# 第517個標的 - 2546
# ✅ 2546 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第518個標的 - 2547 ⚠️ YoY < 10%，跳過
# 第519個標的 - 2548
# 第520個標的 - 2596 ⚠️ YoY < 10%，跳過
# 第521個標的 - 2597
# 第522個標的 - 2601 ⚠️ YoY < 10%，跳過
# 第523個標的 - 2603 ⚠️ YoY < 10%，跳過
# 第524個標的 - 2605
# ✅ 2605 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第525個標的 - 2606
# 第526個標的 - 2607 ⚠️ YoY < 10%，跳過
# 第527個標的 - 2608 ⚠️ YoY < 10%，跳過
# 第528個標的 - 2609 ⚠️ YoY < 10%，跳過
# 第529個標的 - 2610 ⚠️ YoY < 10%，跳過
# 第530個標的 - 2611 ⚠️ YoY < 10%，跳過
# 第531個標的 - 2612
# 第532個標的 - 2613
# ✅ 2613 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第533個標的 - 2614 ⚠️ YoY < 10%，跳過
# 第534個標的 - 2615 ⚠️ YoY < 10%，跳過
# 第535個標的 - 2616 ⚠️ YoY < 10%，跳過
# 第536個標的 - 2617
# ✅ 2617 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第537個標的 - 2618 ⚠️ YoY < 10%，跳過
# 第538個標的 - 2628
# 第539個標的 - 2630 ⚠️ YoY < 10%，跳過
# 第540個標的 - 2633 ⚠️ YoY < 10%，跳過
# 第541個標的 - 2634
# ✅ 2634 - 符合條件（突破 + 後續 3 根站上），加入 long_result ✅
# 第542個標的 - 2636 ⚠️ YoY < 10%，跳過
# 第543個標的 - 2637
# ✅ 2637 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第544個標的 - 2640
# 第545個標的 - 2641
# 第546個標的 - 2642 ⚠️ YoY < 10%，跳過
# 第547個標的 - 2643
# 第548個標的 - 2645 ⚠️ YoY < 10%，跳過
# 第549個標的 - 2646
# 第550個標的 - 2701
# 第551個標的 - 2702 ⚠️ YoY < 10%，跳過
# 第552個標的 - 2704 ⚠️ YoY < 10%，跳過
# 第553個標的 - 2705 ⚠️ YoY < 10%，跳過
# 第554個標的 - 2706 ⚠️ YoY < 10%，跳過
# 第555個標的 - 2707 ⚠️ YoY < 10%，跳過
# 第556個標的 - 2712 ⚠️ YoY < 10%，跳過
# 第557個標的 - 2718
# 第558個標的 - 2719 ⚠️ YoY < 10%，跳過
# 第559個標的 - 2722 ⚠️ YoY < 10%，跳過
# 第560個標的 - 2723 ⚠️ YoY < 10%，跳過
# 第561個標的 - 2724
# 第562個標的 - 2726 ⚠️ YoY < 10%，跳過
# 第563個標的 - 2727
# 第564個標的 - 2729
# 第565個標的 - 2731
# ✅ 2731 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第566個標的 - 2732
# 第567個標的 - 2734
# 第568個標的 - 2736
# 第569個標的 - 2739
# 第570個標的 - 2740 ⚠️ YoY < 10%，跳過
# 第571個標的 - 2743
# ✅ 2743 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第572個標的 - 2745
# 第573個標的 - 2748 ⚠️ YoY < 10%，跳過
# 第574個標的 - 2751
# 第575個標的 - 2752
# 第576個標的 - 2753
# 第577個標的 - 2754 ⚠️ YoY < 10%，跳過
# 第578個標的 - 2755
# 第579個標的 - 2756
# 第580個標的 - 2762
# 第581個標的 - 2801
# 第582個標的 - 2809
# 第583個標的 - 2812
# 第584個標的 - 2816 ⚠️ YoY < 10%，跳過
# 第585個標的 - 2820
# 第586個標的 - 2823
# 第587個標的 - 2827
# 第588個標的 - 2832 ⚠️ YoY < 10%，跳過
# 第589個標的 - 2833
# 第590個標的 - 2834 ⚠️ YoY < 10%，跳過
# 第591個標的 - 2836
# 第592個標的 - 2837
# 第593個標的 - 2838
# 第594個標的 - 2841
# 第595個標的 - 2845
# 第596個標的 - 2847
# 第597個標的 - 2849
# 第598個標的 - 2850 ⚠️ YoY < 10%，跳過
# 第599個標的 - 2851
# ✅ 2851 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第600個標的 - 2852
# 第601個標的 - 2854
# 第602個標的 - 2855
# ✅ 2855 - 符合條件（突破 + 後續 2 根站上），加入 long_result ✅
# 第603個標的 - 2856
# 第604個標的 - 2867 ⚠️ YoY < 10%，跳過
# 第605個標的 - 2880
# 第606個標的 - 2881
# 第607個標的 - 2882
# 第608個標的 - 2883
# 第609個標的 - 2884
# 第610個標的 - 2885
# ❌ 2885 - 第-2根不符合，open 或 close 未高於上軌 ❌
# 第611個標的 - 2886
# 第612個標的 - 2887
# 第613個標的 - 2888 ⚠️ YoY < 10%，跳過
# 第614個標的 - 2889
# ✅ 2889 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第615個標的 - 2890
# ✅ 2890 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第616個標的 - 2891
# 第617個標的 - 2892
# 第618個標的 - 2897
# 第619個標的 - 2901 ⚠️ YoY < 10%，跳過
# 第620個標的 - 2903 ⚠️ YoY < 10%，跳過
# 第621個標的 - 2904 ⚠️ YoY < 10%，跳過
# 第622個標的 - 2905 ⚠️ YoY < 10%，跳過
# 第623個標的 - 2906
# 第624個標的 - 2908 ⚠️ YoY < 10%，跳過
# 第625個標的 - 2910 ⚠️ YoY < 10%，跳過
# 第626個標的 - 2911 ⚠️ YoY < 10%，跳過
# 第627個標的 - 2912 ⚠️ YoY < 10%，跳過
# 第628個標的 - 2913 ⚠️ YoY < 10%，跳過
# 第629個標的 - 2915 ⚠️ YoY < 10%，跳過
# 第630個標的 - 2916 ⚠️ YoY < 10%，跳過
# 第631個標的 - 2921
# 第632個標的 - 2923 ⚠️ YoY < 10%，跳過
# 第633個標的 - 2924
# 第634個標的 - 2926 ⚠️ YoY < 10%，跳過
# 第635個標的 - 2928
# 第636個標的 - 2929 ⚠️ YoY < 10%，跳過
# 第637個標的 - 2936
# 第638個標的 - 2937
# 第639個標的 - 2939 ⚠️ YoY < 10%，跳過
# 第640個標的 - 2941 ⚠️ YoY < 10%，跳過
# 第641個標的 - 2945
# 第642個標的 - 2947 ⚠️ YoY < 10%，跳過
# 第643個標的 - 2948 ⚠️ YoY < 10%，跳過
# 第644個標的 - 2949
# 第645個標的 - 3002 ⚠️ YoY < 10%，跳過
# 第646個標的 - 3003 ⚠️ YoY < 10%，跳過
# 第647個標的 - 3004
# 第648個標的 - 3005
# 第649個標的 - 3006
# 第650個標的 - 3008 ⚠️ YoY < 10%，跳過
# 第651個標的 - 3009
# 第652個標的 - 3010 ⚠️ YoY < 10%，跳過
# 第653個標的 - 3011 ⚠️ YoY < 10%，跳過
# 第654個標的 - 3013
# 第655個標的 - 3014 ⚠️ YoY < 10%，跳過
# 第656個標的 - 3015 ⚠️ YoY < 10%，跳過
# 第657個標的 - 3016
# 第658個標的 - 3017
# 第659個標的 - 3018 ⚠️ YoY < 10%，跳過
# 第660個標的 - 3019 ⚠️ YoY < 10%，跳過
# 第661個標的 - 3020
# 第662個標的 - 3021
# ❌ 3021 - 第-2根不符合，open 或 close 未高於上軌 ❌
# 第663個標的 - 3022
# 第664個標的 - 3023 ⚠️ YoY < 10%，跳過
# 第665個標的 - 3024 ⚠️ YoY < 10%，跳過
# 第666個標的 - 3025
# ✅ 3025 - 符合條件（突破 + 後續 2 根站上），加入 long_result ✅
# 第667個標的 - 3026
# 第668個標的 - 3027 ⚠️ YoY < 10%，跳過
# 第669個標的 - 3028
# ❌ 3028 - 第-2根不符合，open 或 close 未高於上軌 ❌
# 第670個標的 - 3029 ⚠️ YoY < 10%，跳過
# 第671個標的 - 3030
# 第672個標的 - 3031 ⚠️ YoY < 10%，跳過
# 第673個標的 - 3032
# 第674個標的 - 3033 ⚠️ YoY < 10%，跳過
# 第675個標的 - 3034 ⚠️ YoY < 10%，跳過
# 第676個標的 - 3035 ⚠️ YoY < 10%，跳過
# 第677個標的 - 3036 ⚠️ YoY < 10%，跳過
# 第678個標的 - 3037
# 第679個標的 - 3038 ⚠️ YoY < 10%，跳過
# 第680個標的 - 3040 ⚠️ YoY < 10%，跳過
# 第681個標的 - 3041
# 第682個標的 - 3042 ⚠️ YoY < 10%，跳過
# 第683個標的 - 3043 ⚠️ YoY < 10%，跳過
# 第684個標的 - 3044
# 第685個標的 - 3045 ⚠️ YoY < 10%，跳過
# 第686個標的 - 3046
# ✅ 3046 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第687個標的 - 3047 ⚠️ YoY < 10%，跳過
# 第688個標的 - 3048 ⚠️ YoY < 10%，跳過
# 第689個標的 - 3049
# 第690個標的 - 3050
# 第691個標的 - 3051 ⚠️ YoY < 10%，跳過
# 第692個標的 - 3052
# 第693個標的 - 3053
# 第694個標的 - 3054 ⚠️ YoY < 10%，跳過
# 第695個標的 - 3055
# 第696個標的 - 3056 ⚠️ YoY < 10%，跳過
# 第697個標的 - 3057 ⚠️ YoY < 10%，跳過
# 第698個標的 - 3058 ⚠️ YoY < 10%，跳過
# 第699個標的 - 3059 ⚠️ YoY < 10%，跳過
# 第700個標的 - 3060 ⚠️ YoY < 10%，跳過
# 第701個標的 - 3061
# 第702個標的 - 3062 ⚠️ YoY < 10%，跳過
# 第703個標的 - 3063
# 第704個標的 - 3064 ⚠️ YoY < 10%，跳過
# 第705個標的 - 3066
# 第706個標的 - 3067
# 第707個標的 - 3068
# 第708個標的 - 3069
# 第709個標的 - 3071
# ❌ 3071 - 第-2根不符合，open 或 close 未高於上軌 ❌
# 第710個標的 - 3073
# 第711個標的 - 3078 ⚠️ YoY < 10%，跳過
# 第712個標的 - 3079
# 第713個標的 - 3080
# 第714個標的 - 3081
# ❌ 3081 - 第-2根不符合，open 或 close 未高於上軌 ❌
# 第715個標的 - 3083
# 第716個標的 - 3085 ⚠️ YoY < 10%，跳過
# 第717個標的 - 3086
# 第718個標的 - 3087
# 第719個標的 - 3088
# ✅ 3088 - 符合條件（突破 + 後續 2 根站上），加入 long_result ✅
# 第720個標的 - 3089
# 第721個標的 - 3090
# 第722個標的 - 3092 ⚠️ YoY < 10%，跳過
# 第723個標的 - 3093 ⚠️ YoY < 10%，跳過
# 第724個標的 - 3094 ⚠️ YoY < 10%，跳過
# 第725個標的 - 3095
# 第726個標的 - 3099
# 第727個標的 - 3105
# ✅ 3105 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第728個標的 - 3114 ⚠️ YoY < 10%，跳過
# 第729個標的 - 3115 ⚠️ YoY < 10%，跳過
# 第730個標的 - 3118
# 第731個標的 - 3122 ⚠️ YoY < 10%，跳過
# 第732個標的 - 3126
# 第733個標的 - 3128 ⚠️ YoY < 10%，跳過
# 第734個標的 - 3130
# 第735個標的 - 3131
# 第736個標的 - 3135
# 第737個標的 - 3138
# ✅ 3138 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第738個標的 - 3141 ⚠️ YoY < 10%，跳過
# 第739個標的 - 3142
# 第740個標的 - 3144
# 第741個標的 - 3147 ⚠️ YoY < 10%，跳過
# 第742個標的 - 3149
# 第743個標的 - 3150 ⚠️ YoY < 10%，跳過
# 第744個標的 - 3152 ⚠️ YoY < 10%，跳過
# 第745個標的 - 3158 ⚠️ YoY < 10%，跳過
# 第746個標的 - 3162
# 第747個標的 - 3163
# 第748個標的 - 3164 ⚠️ YoY < 10%，跳過
# 第749個標的 - 3167
# 第750個標的 - 3168
# 第751個標的 - 3169 ⚠️ YoY < 10%，跳過
# 第752個標的 - 3171
# 第753個標的 - 3176 ⚠️ YoY < 10%，跳過
# 第754個標的 - 3178 ⚠️ YoY < 10%，跳過
# 第755個標的 - 3188
# 第756個標的 - 3189
# 第757個標的 - 3191 ⚠️ YoY < 10%，跳過
# 第758個標的 - 3205 ⚠️ YoY < 10%，跳過
# 第759個標的 - 3206 ⚠️ YoY < 10%，跳過
# 第760個標的 - 3207
# 第761個標的 - 3209 ⚠️ YoY < 10%，跳過
# 第762個標的 - 3211
# 第763個標的 - 3213
# 第764個標的 - 3217
# 第765個標的 - 3218 ⚠️ YoY < 10%，跳過
# 第766個標的 - 3219
# 第767個標的 - 3221
# 第768個標的 - 3224
# ✅ 3224 - 符合條件（突破 + 後續 2 根站上），加入 long_result ✅
# 第769個標的 - 3226 ⚠️ YoY < 10%，跳過
# 第770個標的 - 3227 ⚠️ YoY < 10%，跳過
# 第771個標的 - 3228
# 第772個標的 - 3229
# 第773個標的 - 3230 ⚠️ YoY < 10%，跳過
# 第774個標的 - 3231
# 第775個標的 - 3232 ⚠️ YoY < 10%，跳過
# 第776個標的 - 3234
# 第777個標的 - 3236
# 第778個標的 - 3252 ⚠️ YoY < 10%，跳過
# 第779個標的 - 3257
# 第780個標的 - 3259 ⚠️ YoY < 10%，跳過
# 第781個標的 - 3260
# 第782個標的 - 3264
# 第783個標的 - 3265
# 第784個標的 - 3266 ⚠️ YoY < 10%，跳過
# 第785個標的 - 3268 ⚠️ YoY < 10%，跳過
# 第786個標的 - 3271
# 第787個標的 - 3272 ⚠️ YoY < 10%，跳過
# 第788個標的 - 3276 ⚠️ YoY < 10%，跳過
# 第789個標的 - 3284
# 第790個標的 - 3285
# 第791個標的 - 3287
# 第792個標的 - 3288 ⚠️ YoY < 10%，跳過
# 第793個標的 - 3289
# 第794個標的 - 3290
# ❌ 3290 - 第-1根不符合，open 或 close 未高於上軌 ❌
# 第795個標的 - 3291
# 第796個標的 - 3293
# ✅ 3293 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第797個標的 - 3294 ⚠️ YoY < 10%，跳過
# 第798個標的 - 3296 ⚠️ YoY < 10%，跳過
# 第799個標的 - 3297
# 第800個標的 - 3298
# 第801個標的 - 3299
# 第802個標的 - 3303 ⚠️ YoY < 10%，跳過
# 第803個標的 - 3305
# 第804個標的 - 3306
# 第805個標的 - 3308
# 第806個標的 - 3310
# 第807個標的 - 3311 ⚠️ YoY < 10%，跳過
# 第808個標的 - 3312
# 第809個標的 - 3313 ⚠️ YoY < 10%，跳過
# 第810個標的 - 3315
# 第811個標的 - 3317 ⚠️ YoY < 10%，跳過
# 第812個標的 - 3321 ⚠️ YoY < 10%，跳過
# 第813個標的 - 3322 ⚠️ YoY < 10%，跳過
# 第814個標的 - 3323 ⚠️ YoY < 10%，跳過
# 第815個標的 - 3324
# 第816個標的 - 3325
# 第817個標的 - 3332 ⚠️ YoY < 10%，跳過
# 第818個標的 - 3338 ⚠️ YoY < 10%，跳過
# 第819個標的 - 3339
# 第820個標的 - 3346 ⚠️ YoY < 10%，跳過
# 第821個標的 - 3349 ⚠️ YoY < 10%，跳過
# 第822個標的 - 3354
# 第823個標的 - 3356 ⚠️ YoY < 10%，跳過
# 第824個標的 - 3357
# 第825個標的 - 3360
# 第826個標的 - 3362 ⚠️ YoY < 10%，跳過
# 第827個標的 - 3363
# 第828個標的 - 3367
# 第829個標的 - 3369
# 第830個標的 - 3372
# ✅ 3372 - 符合條件（突破 + 後續 2 根站上），加入 long_result ✅
# 第831個標的 - 3373 ⚠️ YoY < 10%，跳過
# 第832個標的 - 3374
# 第833個標的 - 3376 ⚠️ YoY < 10%，跳過
# 第834個標的 - 3379
# 第835個標的 - 3380
# ❌ 3380 - 第-3根不符合，open 或 close 未高於上軌 ❌
# 第836個標的 - 3383
# 第837個標的 - 3388
# 第838個標的 - 3389
# 第839個標的 - 3390
# 第840個標的 - 3402 ⚠️ YoY < 10%，跳過
# 第841個標的 - 3406
# 第842個標的 - 3413 ⚠️ YoY < 10%，跳過
# 第843個標的 - 3416
# 第844個標的 - 3419 ⚠️ YoY < 10%，跳過
# 第845個標的 - 3426 ⚠️ YoY < 10%，跳過
# 第846個標的 - 3428
# 第847個標的 - 3430
# 第848個標的 - 3431
# 第849個標的 - 3432
# 第850個標的 - 3434 ⚠️ YoY < 10%，跳過
# 第851個標的 - 3437 ⚠️ YoY < 10%，跳過
# 第852個標的 - 3438 ⚠️ YoY < 10%，跳過
# 第853個標的 - 3441
# 第854個標的 - 3443
# 第855個標的 - 3444
# 第856個標的 - 3447
# 第857個標的 - 3450 ⚠️ YoY < 10%，跳過
# 第858個標的 - 3452
# 第859個標的 - 3454 ⚠️ YoY < 10%，跳過
# 第860個標的 - 3455 ⚠️ YoY < 10%，跳過
# 第861個標的 - 3465 ⚠️ YoY < 10%，跳過
# 第862個標的 - 3466 ⚠️ YoY < 10%，跳過
# 第863個標的 - 3467 ⚠️ YoY < 10%，跳過
# 第864個標的 - 3474
# 第865個標的 - 3479
# 第866個標的 - 3481
# 第867個標的 - 3483 ⚠️ YoY < 10%，跳過
# 第868個標的 - 3484 ⚠️ YoY < 10%，跳過
# 第869個標的 - 3489 ⚠️ YoY < 10%，跳過
# 第870個標的 - 3490 ⚠️ YoY < 10%，跳過
# 第871個標的 - 3491
# 第872個標的 - 3492 ⚠️ YoY < 10%，跳過
# 第873個標的 - 3494
# 第874個標的 - 3498
# ✅ 3498 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第875個標的 - 3499 ⚠️ YoY < 10%，跳過
# 第876個標的 - 3501 ⚠️ YoY < 10%，跳過
# 第877個標的 - 3504 ⚠️ YoY < 10%，跳過
# 第878個標的 - 3508
# ❌ 3508 - 第-2根不符合，open 或 close 未高於上軌 ❌
# 第879個標的 - 3511 ⚠️ YoY < 10%，跳過
# 第880個標的 - 3512 ⚠️ YoY < 10%，跳過
# 第881個標的 - 3514
# 第882個標的 - 3515
# 第883個標的 - 3516 ⚠️ YoY < 10%，跳過
# 第884個標的 - 3518
# 第885個標的 - 3519
# 第886個標的 - 3520 ⚠️ YoY < 10%，跳過
# 第887個標的 - 3521
# 第888個標的 - 3522 ⚠️ YoY < 10%，跳過
# 第889個標的 - 3523 ⚠️ YoY < 10%，跳過
# 第890個標的 - 3526
# ✅ 3526 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第891個標的 - 3527 ⚠️ YoY < 10%，跳過
# 第892個標的 - 3528
# 第893個標的 - 3529 ⚠️ YoY < 10%，跳過
# 第894個標的 - 3530
# 第895個標的 - 3531 ⚠️ YoY < 10%，跳過
# 第896個標的 - 3532 ⚠️ YoY < 10%，跳過
# 第897個標的 - 3533
# ✅ 3533 - 符合條件（突破 + 後續 2 根站上），加入 long_result ✅
# 第898個標的 - 3534
# 第899個標的 - 3535
# ✅ 3535 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第900個標的 - 3536
# 第901個標的 - 3537
# 第902個標的 - 3540
# 第903個標的 - 3541
# ✅ 3541 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第904個標的 - 3543 ⚠️ YoY < 10%，跳過
# 第905個標的 - 3545 ⚠️ YoY < 10%，跳過
# 第906個標的 - 3546
# 第907個標的 - 3548 ⚠️ YoY < 10%，跳過
# 第908個標的 - 3550 ⚠️ YoY < 10%，跳過
# 第909個標的 - 3551
# 第910個標的 - 3552 ⚠️ YoY < 10%，跳過
# 第911個標的 - 3553
# 第912個標的 - 3555
# 第913個標的 - 3556
# 第914個標的 - 3557 ⚠️ YoY < 10%，跳過
# 第915個標的 - 3558 ⚠️ YoY < 10%，跳過
# 第916個標的 - 3559
# 第917個標的 - 3561
# 第918個標的 - 3562
# 第919個標的 - 3563
# 第920個標的 - 3564 ⚠️ YoY < 10%，跳過
# 第921個標的 - 3567 ⚠️ YoY < 10%，跳過
# 第922個標的 - 3570
# 第923個標的 - 3573
# 第924個標的 - 3576 ⚠️ YoY < 10%，跳過
# 第925個標的 - 3577
# 第926個標的 - 3579
# 第927個標的 - 3580 ⚠️ YoY < 10%，跳過
# 第928個標的 - 3581
# 第929個標的 - 3582
# 第930個標的 - 3583
# 第931個標的 - 3584
# 第932個標的 - 3587
# 第933個標的 - 3588
# ✅ 3588 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第934個標的 - 3591 ⚠️ YoY < 10%，跳過
# 第935個標的 - 3592 ⚠️ YoY < 10%，跳過
# 第936個標的 - 3593 ⚠️ YoY < 10%，跳過
# 第937個標的 - 3594
# 第938個標的 - 3596 ⚠️ YoY < 10%，跳過
# 第939個標的 - 3597 ⚠️ YoY < 10%，跳過
# 第940個標的 - 3598
# 第941個標的 - 3599
# 第942個標的 - 3605 ⚠️ YoY < 10%，跳過
# 第943個標的 - 3607 ⚠️ YoY < 10%，跳過
# 第944個標的 - 3609
# 第945個標的 - 3611 ⚠️ YoY < 10%，跳過
# 第946個標的 - 3614
# 第947個標的 - 3615 ⚠️ YoY < 10%，跳過
# 第948個標的 - 3617 ⚠️ YoY < 10%，跳過
# 第949個標的 - 3622
# ✅ 3622 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第950個標的 - 3623
# 第951個標的 - 3624
# 第952個標的 - 3625
# 第953個標的 - 3628 ⚠️ YoY < 10%，跳過
# 第954個標的 - 3629
# 第955個標的 - 3630
# ✅ 3630 - 符合條件（突破 + 後續 2 根站上），加入 long_result ✅
# 第956個標的 - 3631
# 第957個標的 - 3632
# 第958個標的 - 3638
# 第959個標的 - 3642
# 第960個標的 - 3645 ⚠️ YoY < 10%，跳過
# 第961個標的 - 3646 ⚠️ YoY < 10%，跳過
# 第962個標的 - 3652 ⚠️ YoY < 10%，跳過
# 第963個標的 - 3653
# 第964個標的 - 3658
# 第965個標的 - 3661 ⚠️ YoY < 10%，跳過
# 第966個標的 - 3662
# 第967個標的 - 3663
# 第968個標的 - 3664 ⚠️ YoY < 10%，跳過
# 第969個標的 - 3665
# 第970個標的 - 3666 ⚠️ YoY < 10%，跳過
# 第971個標的 - 3669
# 第972個標的 - 3672 ⚠️ YoY < 10%，跳過
# 第973個標的 - 3673 ⚠️ YoY < 10%，跳過
# 第974個標的 - 3675 ⚠️ YoY < 10%，跳過
# 第975個標的 - 3679 ⚠️ YoY < 10%，跳過
# 第976個標的 - 3680
# 第977個標的 - 3682
# 第978個標的 - 3684 ⚠️ YoY < 10%，跳過
# 第979個標的 - 3685
# 第980個標的 - 3686
# 第981個標的 - 3687
# 第982個標的 - 3689
# 第983個標的 - 3691
# 第984個標的 - 3693 ⚠️ YoY < 10%，跳過
# 第985個標的 - 3694
# 第986個標的 - 3697
# 第987個標的 - 3698
# 第988個標的 - 3701 ⚠️ YoY < 10%，跳過
# 第989個標的 - 3702
# 第990個標的 - 3703
# 第991個標的 - 3704 ⚠️ YoY < 10%，跳過
# 第992個標的 - 3705 ⚠️ YoY < 10%，跳過
# 第993個標的 - 3706
# 第994個標的 - 3707
# 第995個標的 - 3708 ⚠️ YoY < 10%，跳過
# 第996個標的 - 3709 ⚠️ YoY < 10%，跳過
# 第997個標的 - 3710 ⚠️ YoY < 10%，跳過
# 第998個標的 - 3711
# 第999個標的 - 3712 ⚠️ YoY < 10%，跳過
# 第1000個標的 - 3713
# 第1001個標的 - 3714 ⚠️ YoY < 10%，跳過
# 第1002個標的 - 3715
# ✅ 3715 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第1003個標的 - 3716 ⚠️ YoY < 10%，跳過
# 第1004個標的 - 3717
# 第1005個標的 - 4102
# 第1006個標的 - 4103
# 第1007個標的 - 4104 ⚠️ YoY < 10%，跳過
# 第1008個標的 - 4105 ⚠️ YoY < 10%，跳過
# 第1009個標的 - 4106 ⚠️ YoY < 10%，跳過
# 第1010個標的 - 4107
# ✅ 4107 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第1011個標的 - 4108 ⚠️ YoY < 10%，跳過
# 第1012個標的 - 4109 ⚠️ YoY < 10%，跳過
# 第1013個標的 - 4111 ⚠️ YoY < 10%，跳過
# 第1014個標的 - 4113 ⚠️ YoY < 10%，跳過
# 第1015個標的 - 4114 ⚠️ YoY < 10%，跳過
# 第1016個標的 - 4116
# 第1017個標的 - 4119
# ✅ 4119 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第1018個標的 - 4120
# 第1019個標的 - 4121 ⚠️ YoY < 10%，跳過
# 第1020個標的 - 4123
# ✅ 4123 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第1021個標的 - 4126 ⚠️ YoY < 10%，跳過
# 第1022個標的 - 4127
# 第1023個標的 - 4128
# ✅ 4128 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第1024個標的 - 4129
# 第1025個標的 - 4130 ⚠️ YoY < 10%，跳過
# 第1026個標的 - 4131
# 第1027個標的 - 4133 ⚠️ YoY < 10%，跳過
# 第1028個標的 - 4137
# 第1029個標的 - 4138 ⚠️ YoY < 10%，跳過
# 第1030個標的 - 4139 ⚠️ YoY < 10%，跳過
# 第1031個標的 - 4141
# 第1032個標的 - 4142
# ✅ 4142 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第1033個標的 - 4144
# 第1034個標的 - 4147
# 第1035個標的 - 4148
# 第1036個標的 - 4152
# 第1037個標的 - 4153
# 第1038個標的 - 4154
# 第1039個標的 - 4155 ⚠️ YoY < 10%，跳過
# 第1040個標的 - 4157
# 第1041個標的 - 4160
# 第1042個標的 - 4161 ⚠️ YoY < 10%，跳過
# 第1043個標的 - 4162 ⚠️ YoY < 10%，跳過
# 第1044個標的 - 4163
# 第1045個標的 - 4164
# 第1046個標的 - 4166
# 第1047個標的 - 4167
# ✅ 4167 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第1048個標的 - 4168
# 第1049個標的 - 4171
# 第1050個標的 - 4173
# ✅ 4173 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第1051個標的 - 4174 ⚠️ YoY < 10%，跳過
# 第1052個標的 - 4175 ⚠️ YoY < 10%，跳過
# 第1053個標的 - 4180
# 第1054個標的 - 4183 ⚠️ YoY < 10%，跳過
# 第1055個標的 - 4188 ⚠️ YoY < 10%，跳過
# 第1056個標的 - 4190 ⚠️ YoY < 10%，跳過
# 第1057個標的 - 4192 ⚠️ YoY < 10%，跳過
# 第1058個標的 - 4198 ⚠️ YoY < 10%，跳過
# 第1059個標的 - 4205 ⚠️ YoY < 10%，跳過
# 第1060個標的 - 4207 ⚠️ YoY < 10%，跳過
# 第1061個標的 - 4303
# 第1062個標的 - 4304 ⚠️ YoY < 10%，跳過
# 第1063個標的 - 4305 ⚠️ YoY < 10%，跳過
# 第1064個標的 - 4306
# 第1065個標的 - 4401 ⚠️ YoY < 10%，跳過
# 第1066個標的 - 4402
# 第1067個標的 - 4406 ⚠️ YoY < 10%，跳過
# 第1068個標的 - 4408
# 第1069個標的 - 4413
# 第1070個標的 - 4414 ⚠️ YoY < 10%，跳過
# 第1071個標的 - 4415
# 第1072個標的 - 4416
# 第1073個標的 - 4417 ⚠️ YoY < 10%，跳過
# 第1074個標的 - 4419 ⚠️ YoY < 10%，跳過
# 第1075個標的 - 4420
# 第1076個標的 - 4426
# 第1077個標的 - 4429
# 第1078個標的 - 4430 ⚠️ YoY < 10%，跳過
# 第1079個標的 - 4432
# 第1080個標的 - 4433
# 第1081個標的 - 4438
# 第1082個標的 - 4439
# 第1083個標的 - 4440
# 第1084個標的 - 4441
# 第1085個標的 - 4442 ⚠️ YoY < 10%，跳過
# 第1086個標的 - 4502 ⚠️ YoY < 10%，跳過
# 第1087個標的 - 4503 ⚠️ YoY < 10%，跳過
# 第1088個標的 - 4506 ⚠️ YoY < 10%，跳過
# 第1089個標的 - 4510
# 第1090個標的 - 4513 ⚠️ YoY < 10%，跳過
# 第1091個標的 - 4523 ⚠️ YoY < 10%，跳過
# 第1092個標的 - 4526 ⚠️ YoY < 10%，跳過
# 第1093個標的 - 4527
# ❌ 4527 - 第-1根不符合，open 或 close 未高於上軌 ❌
# 第1094個標的 - 4528
# 第1095個標的 - 4529 ⚠️ YoY < 10%，跳過
# 第1096個標的 - 4530
# 第1097個標的 - 4532 ⚠️ YoY < 10%，跳過
# 第1098個標的 - 4533
# 第1099個標的 - 4534
# 第1100個標的 - 4535 ⚠️ YoY < 10%，跳過
# 第1101個標的 - 4536 ⚠️ YoY < 10%，跳過
# 第1102個標的 - 4538
# 第1103個標的 - 4540 ⚠️ YoY < 10%，跳過
# 第1104個標的 - 4541
# ✅ 4541 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第1105個標的 - 4542
# ✅ 4542 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第1106個標的 - 4543
# 第1107個標的 - 4545 ⚠️ YoY < 10%，跳過
# 第1108個標的 - 4549 ⚠️ YoY < 10%，跳過
# 第1109個標的 - 4550
# 第1110個標的 - 4551
# ✅ 4551 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第1111個標的 - 4552 ⚠️ YoY < 10%，跳過
# 第1112個標的 - 4554 ⚠️ YoY < 10%，跳過
# 第1113個標的 - 4555
# 第1114個標的 - 4556 ⚠️ YoY < 10%，跳過
# 第1115個標的 - 4557 ⚠️ YoY < 10%，跳過
# 第1116個標的 - 4558 ⚠️ YoY < 10%，跳過
# 第1117個標的 - 4560 ⚠️ YoY < 10%，跳過
# 第1118個標的 - 4561 ⚠️ YoY < 10%，跳過
# 第1119個標的 - 4562 ⚠️ YoY < 10%，跳過
# 第1120個標的 - 4563 ⚠️ YoY < 10%，跳過
# 第1121個標的 - 4564 ⚠️ YoY < 10%，跳過
# 第1122個標的 - 4566
# 第1123個標的 - 4568
# 第1124個標的 - 4569
# 第1125個標的 - 4571 ⚠️ YoY < 10%，跳過
# 第1126個標的 - 4572 ⚠️ YoY < 10%，跳過
# 第1127個標的 - 4576
# ✅ 4576 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第1128個標的 - 4577
# 第1129個標的 - 4580 ⚠️ YoY < 10%，跳過
# 第1130個標的 - 4581
# 第1131個標的 - 4583
# ✅ 4583 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第1132個標的 - 4584 ⚠️ YoY < 10%，跳過
# 第1133個標的 - 4585
# 第1134個標的 - 4588
# 第1135個標的 - 4609 ⚠️ YoY < 10%，跳過
# 第1136個標的 - 4702 ⚠️ YoY < 10%，跳過
# 第1137個標的 - 4703
# 第1138個標的 - 4706
# 第1139個標的 - 4707 ⚠️ YoY < 10%，跳過
# 第1140個標的 - 4711
# ✅ 4711 - 符合條件（突破 + 後續 2 根站上），加入 long_result ✅
# 第1141個標的 - 4712
# 第1142個標的 - 4714
# 第1143個標的 - 4716 ⚠️ YoY < 10%，跳過
# 第1144個標的 - 4720 ⚠️ YoY < 10%，跳過
# 第1145個標的 - 4721 ⚠️ YoY < 10%，跳過
# 第1146個標的 - 4722 ⚠️ YoY < 10%，跳過
# 第1147個標的 - 4725
# 第1148個標的 - 4726
# ✅ 4726 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第1149個標的 - 4728
# 第1150個標的 - 4729 ⚠️ YoY < 10%，跳過
# 第1151個標的 - 4733
# 第1152個標的 - 4735
# ❌ 4735 - 第-2根不符合，open 或 close 未高於上軌 ❌
# 第1153個標的 - 4736
# ✅ 4736 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第1154個標的 - 4737
# 第1155個標的 - 4739
# 第1156個標的 - 4741
# 第1157個標的 - 4743
# ✅ 4743 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第1158個標的 - 4744
# 第1159個標的 - 4745 ⚠️ YoY < 10%，跳過
# 第1160個標的 - 4746 ⚠️ YoY < 10%，跳過
# 第1161個標的 - 4747
# 第1162個標的 - 4749
# 第1163個標的 - 4754 ⚠️ YoY < 10%，跳過
# 第1164個標的 - 4755 ⚠️ YoY < 10%，跳過
# 第1165個標的 - 4760
# 第1166個標的 - 4762 ⚠️ 無 YoY 資料，跳過
# 第1167個標的 - 4763 ⚠️ YoY < 10%，跳過
# 第1168個標的 - 4764 ⚠️ YoY < 10%，跳過
# 第1169個標的 - 4766 ⚠️ YoY < 10%，跳過
# 第1170個標的 - 4767 ⚠️ YoY < 10%，跳過
# 第1171個標的 - 4768
# 第1172個標的 - 4770 ⚠️ YoY < 10%，跳過
# 第1173個標的 - 4771
# 第1174個標的 - 4772
# 第1175個標的 - 4801
# 第1176個標的 - 4803
# 第1177個標的 - 4804 ⚠️ YoY < 10%，跳過
# 第1178個標的 - 4806 ⚠️ YoY < 10%，跳過
# 第1179個標的 - 4807 ⚠️ YoY < 10%，跳過
# 第1180個標的 - 4903 ⚠️ YoY < 10%，跳過
# 第1181個標的 - 4904
# 第1182個標的 - 4905
# 第1183個標的 - 4906 ⚠️ YoY < 10%，跳過
# 第1184個標的 - 4907 ⚠️ YoY < 10%，跳過
# 第1185個標的 - 4908 ⚠️ YoY < 10%，跳過
# 第1186個標的 - 4909 ⚠️ YoY < 10%，跳過
# 第1187個標的 - 4911 ⚠️ YoY < 10%，跳過
# 第1188個標的 - 4912 ⚠️ YoY < 10%，跳過
# 第1189個標的 - 4915
# ✅ 4915 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第1190個標的 - 4916
# 第1191個標的 - 4919 ⚠️ YoY < 10%，跳過
# 第1192個標的 - 4923
# 第1193個標的 - 4924 ⚠️ YoY < 10%，跳過
# 第1194個標的 - 4927 ⚠️ YoY < 10%，跳過
# 第1195個標的 - 4930 ⚠️ YoY < 10%，跳過
# 第1196個標的 - 4931
# 第1197個標的 - 4933 ⚠️ YoY < 10%，跳過
# 第1198個標的 - 4934
# 第1199個標的 - 4935 ⚠️ YoY < 10%，跳過
# 第1200個標的 - 4938 ⚠️ YoY < 10%，跳過
# 第1201個標的 - 4939 ⚠️ YoY < 10%，跳過
# 第1202個標的 - 4942 ⚠️ YoY < 10%，跳過
# 第1203個標的 - 4943
# 第1204個標的 - 4944
# 第1205個標的 - 4946
# 第1206個標的 - 4947
# 第1207個標的 - 4949
# 第1208個標的 - 4950 ⚠️ YoY < 10%，跳過
# 第1209個標的 - 4951 ⚠️ YoY < 10%，跳過
# 第1210個標的 - 4952 ⚠️ YoY < 10%，跳過
# 第1211個標的 - 4953
# ✅ 4953 - 符合條件（突破 + 後續 2 根站上），加入 long_result ✅
# 第1212個標的 - 4956 ⚠️ YoY < 10%，跳過
# 第1213個標的 - 4958
# ❌ 4958 - 第-2根不符合，open 或 close 未高於上軌 ❌
# 第1214個標的 - 4960 ⚠️ YoY < 10%，跳過
# 第1215個標的 - 4961 ⚠️ YoY < 10%，跳過
# 第1216個標的 - 4965
# 第1217個標的 - 4966
# ✅ 4966 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第1218個標的 - 4967
# 第1219個標的 - 4968 ⚠️ YoY < 10%，跳過
# 第1220個標的 - 4971
# 第1221個標的 - 4972 ⚠️ YoY < 10%，跳過
# 第1222個標的 - 4973 ⚠️ YoY < 10%，跳過
# 第1223個標的 - 4974 ⚠️ YoY < 10%，跳過
# 第1224個標的 - 4976 ⚠️ YoY < 10%，跳過
# 第1225個標的 - 4977 ⚠️ YoY < 10%，跳過
# 第1226個標的 - 4979
# 第1227個標的 - 4984
# 第1228個標的 - 4987 ⚠️ YoY < 10%，跳過
# 第1229個標的 - 4989
# 第1230個標的 - 4991
# 第1231個標的 - 4994 ⚠️ YoY < 10%，跳過
# 第1232個標的 - 4995
# 第1233個標的 - 4999
# ✅ 4999 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第1234個標的 - 5007 ⚠️ YoY < 10%，跳過
# 第1235個標的 - 5009 ⚠️ YoY < 10%，跳過
# 第1236個標的 - 5011 ⚠️ YoY < 10%，跳過
# 第1237個標的 - 5013 ⚠️ YoY < 10%，跳過
# 第1238個標的 - 5014
# ✅ 5014 - 符合條件（突破 + 後續 2 根站上），加入 long_result ✅
# 第1239個標的 - 5015 ⚠️ YoY < 10%，跳過
# 第1240個標的 - 5016 ⚠️ YoY < 10%，跳過
# 第1241個標的 - 5017
# 第1242個標的 - 5102
# 第1243個標的 - 5201
# 第1244個標的 - 5202 ⚠️ YoY < 10%，跳過
# 第1245個標的 - 5203
# 第1246個標的 - 5204
# 第1247個標的 - 5205 ⚠️ YoY < 10%，跳過
# 第1248個標的 - 5206 ⚠️ YoY < 10%，跳過
# 第1249個標的 - 5207
# 第1250個標的 - 5209
# ✅ 5209 - 符合條件（突破 + 後續 2 根站上），加入 long_result ✅
# 第1251個標的 - 5210
# 第1252個標的 - 5211
# 第1253個標的 - 5212
# 第1254個標的 - 5213
# ✅ 5213 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第1255個標的 - 5215 ⚠️ YoY < 10%，跳過
# 第1256個標的 - 5220 ⚠️ YoY < 10%，跳過
# 第1257個標的 - 5222 ⚠️ YoY < 10%，跳過
# 第1258個標的 - 5223
# ✅ 5223 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第1259個標的 - 5225 ⚠️ YoY < 10%，跳過
# 第1260個標的 - 5227 ⚠️ YoY < 10%，跳過
# 第1261個標的 - 5228
# 第1262個標的 - 5230 ⚠️ YoY < 10%，跳過
# 第1263個標的 - 5234
# 第1264個標的 - 5236 ⚠️ YoY < 10%，跳過
# 第1265個標的 - 5243 ⚠️ YoY < 10%，跳過
# 第1266個標的 - 5244 ⚠️ YoY < 10%，跳過
# 第1267個標的 - 5245 ⚠️ YoY < 10%，跳過
# 第1268個標的 - 5251 ⚠️ YoY < 10%，跳過
# 第1269個標的 - 5255
# 第1270個標的 - 5258
# 第1271個標的 - 5259
# 第1272個標的 - 5261 ⚠️ 無 YoY 資料，跳過
# 第1273個標的 - 5263 ⚠️ YoY < 10%，跳過
# 第1274個標的 - 5264
# 第1275個標的 - 5266 ⚠️ 無 YoY 資料，跳過
# 第1276個標的 - 5269
# ✅ 5269 - 符合條件（突破 + 後續 2 根站上），加入 long_result ✅
# 第1277個標的 - 5272 ⚠️ YoY < 10%，跳過
# 第1278個標的 - 5274
# 第1279個標的 - 5276 ⚠️ YoY < 10%，跳過
# 第1280個標的 - 5278
# 第1281個標的 - 5280 ⚠️ 無 YoY 資料，跳過
# 第1282個標的 - 5281
# 第1283個標的 - 5283 ⚠️ YoY < 10%，跳過
# 第1284個標的 - 5284
# 第1285個標的 - 5285
# ❌ 5285 - 第-2根不符合，open 或 close 未高於上軌 ❌
# 第1286個標的 - 5287 ⚠️ YoY < 10%，跳過
# 第1287個標的 - 5288 ⚠️ YoY < 10%，跳過
# 第1288個標的 - 5289
# 第1289個標的 - 5291
# 第1290個標的 - 5292
# 第1291個標的 - 5299 ⚠️ YoY < 10%，跳過
# 第1292個標的 - 5301 ⚠️ YoY < 10%，跳過
# 第1293個標的 - 5302
# 第1294個標的 - 5304
# 第1295個標的 - 5305
# 第1296個標的 - 5306 ⚠️ YoY < 10%，跳過
# 第1297個標的 - 5309
# 第1298個標的 - 5310 ⚠️ YoY < 10%，跳過
# 第1299個標的 - 5312
# 第1300個標的 - 5314
# 第1301個標的 - 5315 ⚠️ YoY < 10%，跳過
# 第1302個標的 - 5317
# 第1303個標的 - 5318
# 第1304個標的 - 5321 ⚠️ YoY < 10%，跳過
# 第1305個標的 - 5324 ⚠️ YoY < 10%，跳過
# 第1306個標的 - 5328 ⚠️ YoY < 10%，跳過
# 第1307個標的 - 5340
# 第1308個標的 - 5344
# 第1309個標的 - 5345
# ✅ 5345 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第1310個標的 - 5346
# 第1311個標的 - 5347
# ✅ 5347 - 符合條件（突破 + 後續 2 根站上），加入 long_result ✅
# 第1312個標的 - 5348 ⚠️ YoY < 10%，跳過
# 第1313個標的 - 5349
# 第1314個標的 - 5351
# 第1315個標的 - 5353
# 第1316個標的 - 5355
# 第1317個標的 - 5356 ⚠️ YoY < 10%，跳過
# 第1318個標的 - 5364 ⚠️ YoY < 10%，跳過
# 第1319個標的 - 5371
# 第1320個標的 - 5376
# 第1321個標的 - 5381
# 第1322個標的 - 5383
# 第1323個標的 - 5384
# 第1324個標的 - 5386
# 第1325個標的 - 5387
# 第1326個標的 - 5388
# 第1327個標的 - 5392 ⚠️ YoY < 10%，跳過
# 第1328個標的 - 5395
# 第1329個標的 - 5398 ⚠️ YoY < 10%，跳過
# 第1330個標的 - 5403 ⚠️ YoY < 10%，跳過
# 第1331個標的 - 5410 ⚠️ YoY < 10%，跳過
# 第1332個標的 - 5414
# 第1333個標的 - 5425 ⚠️ YoY < 10%，跳過
# 第1334個標的 - 5426 ⚠️ YoY < 10%，跳過
# 第1335個標的 - 5432
# 第1336個標的 - 5434
# ❌ 5434 - 第-2根不符合，open 或 close 未高於上軌 ❌
# 第1337個標的 - 5438 ⚠️ YoY < 10%，跳過
# 第1338個標的 - 5439
# 第1339個標的 - 5443 ⚠️ YoY < 10%，跳過
# 第1340個標的 - 5450 ⚠️ YoY < 10%，跳過
# 第1341個標的 - 5452 ⚠️ YoY < 10%，跳過
# 第1342個標的 - 5455 ⚠️ YoY < 10%，跳過
# 第1343個標的 - 5457 ⚠️ YoY < 10%，跳過
# 第1344個標的 - 5460 ⚠️ YoY < 10%，跳過
# 第1345個標的 - 5464
# 第1346個標的 - 5465 ⚠️ YoY < 10%，跳過
# 第1347個標的 - 5466
# 第1348個標的 - 5467
# 第1349個標的 - 5468
# 第1350個標的 - 5469
# 第1351個標的 - 5471 ⚠️ YoY < 10%，跳過
# 第1352個標的 - 5474
# 第1353個標的 - 5475
# 第1354個標的 - 5478
# ✅ 5478 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第1355個標的 - 5480
# 第1356個標的 - 5481 ⚠️ YoY < 10%，跳過
# 第1357個標的 - 5483
# 第1358個標的 - 5484
# ❌ 5484 - 第-2根不符合，open 或 close 未高於上軌 ❌
# 第1359個標的 - 5487 ⚠️ YoY < 10%，跳過
# 第1360個標的 - 5488 ⚠️ YoY < 10%，跳過
# 第1361個標的 - 5489
# 第1362個標的 - 5490
# 第1363個標的 - 5491
# 第1364個標的 - 5492
# 第1365個標的 - 5493
# ❌ 5493 - 第-2根不符合，open 或 close 未高於上軌 ❌
# 第1366個標的 - 5498
# 第1367個標的 - 5501
# 第1368個標的 - 5505
# 第1369個標的 - 5506
# 第1370個標的 - 5508
# 第1371個標的 - 5511
# 第1372個標的 - 5512
# 第1373個標的 - 5514 ⚠️ YoY < 10%，跳過
# 第1374個標的 - 5515
# 第1375個標的 - 5516
# 第1376個標的 - 5519 ⚠️ YoY < 10%，跳過
# 第1377個標的 - 5520 ⚠️ YoY < 10%，跳過
# 第1378個標的 - 5521
# 第1379個標的 - 5522
# 第1380個標的 - 5523 ⚠️ YoY < 10%，跳過
# 第1381個標的 - 5525
# 第1382個標的 - 5529 ⚠️ YoY < 10%，跳過
# 第1383個標的 - 5530 ⚠️ YoY < 10%，跳過
# 第1384個標的 - 5531 ⚠️ YoY < 10%，跳過
# 第1385個標的 - 5533
# 第1386個標的 - 5534 ⚠️ YoY < 10%，跳過
# 第1387個標的 - 5536
# ❌ 5536 - 第-3根不符合，open 或 close 未高於上軌 ❌
# 第1388個標的 - 5538 ⚠️ YoY < 10%，跳過
# 第1389個標的 - 5543 ⚠️ YoY < 10%，跳過
# 第1390個標的 - 5546 ⚠️ YoY < 10%，跳過
# 第1391個標的 - 5548
# 第1392個標的 - 5601 ⚠️ YoY < 10%，跳過
# 第1393個標的 - 5603 ⚠️ YoY < 10%，跳過
# 第1394個標的 - 5604 ⚠️ YoY < 10%，跳過
# 第1395個標的 - 5605
# 第1396個標的 - 5607
# 第1397個標的 - 5608 ⚠️ YoY < 10%，跳過
# 第1398個標的 - 5609 ⚠️ YoY < 10%，跳過
# 第1399個標的 - 5701
# 第1400個標的 - 5703 ⚠️ YoY < 10%，跳過
# 第1401個標的 - 5704
# 第1402個標的 - 5706 ⚠️ YoY < 10%，跳過
# 第1403個標的 - 5810
# 第1404個標的 - 5818
# 第1405個標的 - 5820
# 第1406個標的 - 5854
# 第1407個標的 - 5864
# 第1408個標的 - 5871 ⚠️ YoY < 10%，跳過
# 第1409個標的 - 5876 ⚠️ YoY < 10%，跳過
# 第1410個標的 - 5878 ⚠️ YoY < 10%，跳過
# 第1411個標的 - 5880
# 第1412個標的 - 5902
# 第1413個標的 - 5903
# 第1414個標的 - 5904 ⚠️ YoY < 10%，跳過
# 第1415個標的 - 5905
# 第1416個標的 - 5906 ⚠️ YoY < 10%，跳過
# 第1417個標的 - 5907 ⚠️ YoY < 10%，跳過
# 第1418個標的 - 6005
# ✅ 6005 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第1419個標的 - 6008
# 第1420個標的 - 6012
# 第1421個標的 - 6015
# ✅ 6015 - 符合條件（突破 + 後續 3 根站上），加入 long_result ✅
# 第1422個標的 - 6016
# 第1423個標的 - 6020 ⚠️ YoY < 10%，跳過
# 第1424個標的 - 6021
# 第1425個標的 - 6022
# 第1426個標的 - 6023
# 第1427個標的 - 6024 ⚠️ YoY < 10%，跳過
# 第1428個標的 - 6026
# 第1429個標的 - 6101 ⚠️ YoY < 10%，跳過
# 第1430個標的 - 6103
# 第1431個標的 - 6104
# 第1432個標的 - 6105
# 第1433個標的 - 6107
# 第1434個標的 - 6108 ⚠️ YoY < 10%，跳過
# 第1435個標的 - 6109
# 第1436個標的 - 6110
# 第1437個標的 - 6111
# 第1438個標的 - 6112
# 第1439個標的 - 6113 ⚠️ YoY < 10%，跳過
# 第1440個標的 - 6114 ⚠️ YoY < 10%，跳過
# 第1441個標的 - 6115
# 第1442個標的 - 6116 ⚠️ YoY < 10%，跳過
# 第1443個標的 - 6117
# 第1444個標的 - 6118
# 第1445個標的 - 6119
# 第1446個標的 - 6120 ⚠️ YoY < 10%，跳過
# 第1447個標的 - 6121
# 第1448個標的 - 6122
# 第1449個標的 - 6123 ⚠️ YoY < 10%，跳過
# 第1450個標的 - 6124 ⚠️ YoY < 10%，跳過
# 第1451個標的 - 6125
# ❌ 6125 - 第-2根不符合，open 或 close 未高於上軌 ❌
# 第1452個標的 - 6126
# 第1453個標的 - 6127
# 第1454個標的 - 6128 ⚠️ YoY < 10%，跳過
# 第1455個標的 - 6129 ⚠️ YoY < 10%，跳過
# 第1456個標的 - 6130 ⚠️ YoY < 10%，跳過
# 第1457個標的 - 6131
# 第1458個標的 - 6133
# 第1459個標的 - 6134
# 第1460個標的 - 6135
# 第1461個標的 - 6136
# 第1462個標的 - 6138
# 第1463個標的 - 6139
# ❌ 6139 - 第-3根不符合，open 或 close 未高於上軌 ❌
# 第1464個標的 - 6140 ⚠️ YoY < 10%，跳過
# 第1465個標的 - 6141
# ✅ 6141 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第1466個標的 - 6142
# 第1467個標的 - 6143 ⚠️ YoY < 10%，跳過
# 第1468個標的 - 6144 ⚠️ YoY < 10%，跳過
# 第1469個標的 - 6145
# 第1470個標的 - 6146 ⚠️ YoY < 10%，跳過
# 第1471個標的 - 6147 ⚠️ YoY < 10%，跳過
# 第1472個標的 - 6148 ⚠️ YoY < 10%，跳過
# 第1473個標的 - 6149
# 第1474個標的 - 6150
# 第1475個標的 - 6151
# ❌ 6151 - 第-1根不符合，open 或 close 未高於上軌 ❌
# 第1476個標的 - 6152 ⚠️ YoY < 10%，跳過
# 第1477個標的 - 6153 ⚠️ YoY < 10%，跳過
# 第1478個標的 - 6154
# 第1479個標的 - 6155
# 第1480個標的 - 6156 ⚠️ YoY < 10%，跳過
# 第1481個標的 - 6158 ⚠️ YoY < 10%，跳過
# 第1482個標的 - 6159
# 第1483個標的 - 6160 ⚠️ YoY < 10%，跳過
# 第1484個標的 - 6161
# ✅ 6161 - 符合條件（突破 + 後續 2 根站上），加入 long_result ✅
# 第1485個標的 - 6163
# ✅ 6163 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第1486個標的 - 6164 ⚠️ YoY < 10%，跳過
# 第1487個標的 - 6165
# 第1488個標的 - 6166 ⚠️ YoY < 10%，跳過
# 第1489個標的 - 6167
# ✅ 6167 - 符合條件（突破 + 後續 2 根站上），加入 long_result ✅
# 第1490個標的 - 6168
# ❌ 6168 - 第-1根不符合，open 或 close 未高於上軌 ❌
# 第1491個標的 - 6169
# 第1492個標的 - 6170 ⚠️ YoY < 10%，跳過
# 第1493個標的 - 6171 ⚠️ YoY < 10%，跳過
# 第1494個標的 - 6172
# 第1495個標的 - 6173
# 第1496個標的 - 6174
# 第1497個標的 - 6175
# 第1498個標的 - 6176 ⚠️ YoY < 10%，跳過
# 第1499個標的 - 6177
# 第1500個標的 - 6179
# 第1501個標的 - 6180
# 第1502個標的 - 6182
# 第1503個標的 - 6183 ⚠️ YoY < 10%，跳過
# 第1504個標的 - 6184 ⚠️ YoY < 10%，跳過
# 第1505個標的 - 6185 ⚠️ YoY < 10%，跳過
# 第1506個標的 - 6186 ⚠️ YoY < 10%，跳過
# 第1507個標的 - 6187 ⚠️ YoY < 10%，跳過
# 第1508個標的 - 6188 ⚠️ YoY < 10%，跳過
# 第1509個標的 - 6189 ⚠️ YoY < 10%，跳過
# 第1510個標的 - 6190
# ❌ 6190 - 第-1根不符合，open 或 close 未高於上軌 ❌
# 第1511個標的 - 6191
# 第1512個標的 - 6192
# 第1513個標的 - 6194 ⚠️ YoY < 10%，跳過
# 第1514個標的 - 6195 ⚠️ YoY < 10%，跳過
# 第1515個標的 - 6196 ⚠️ YoY < 10%，跳過
# 第1516個標的 - 6197
# 第1517個標的 - 6198
# 第1518個標的 - 6199
# 第1519個標的 - 6201 ⚠️ YoY < 10%，跳過
# 第1520個標的 - 6202 ⚠️ YoY < 10%，跳過
# 第1521個標的 - 6203
# 第1522個標的 - 6204
# 第1523個標的 - 6205 ⚠️ YoY < 10%，跳過
# 第1524個標的 - 6206 ⚠️ YoY < 10%，跳過
# 第1525個標的 - 6207 ⚠️ YoY < 10%，跳過
# 第1526個標的 - 6208 ⚠️ YoY < 10%，跳過
# 第1527個標的 - 6209
# 第1528個標的 - 6210
# 第1529個標的 - 6211
# 第1530個標的 - 6212 ⚠️ YoY < 10%，跳過
# 第1531個標的 - 6213
# 第1532個標的 - 6214
# 第1533個標的 - 6215
# 第1534個標的 - 6216 ⚠️ YoY < 10%，跳過
# 第1535個標的 - 6217
# 第1536個標的 - 6218 ⚠️ YoY < 10%，跳過
# 第1537個標的 - 6219 ⚠️ YoY < 10%，跳過
# 第1538個標的 - 6220 ⚠️ YoY < 10%，跳過
# 第1539個標的 - 6221 ⚠️ YoY < 10%，跳過
# 第1540個標的 - 6222 ⚠️ YoY < 10%，跳過
# 第1541個標的 - 6223
# 第1542個標的 - 6224 ⚠️ YoY < 10%，跳過
# 第1543個標的 - 6225
# 第1544個標的 - 6226 ⚠️ YoY < 10%，跳過
# 第1545個標的 - 6227
# 第1546個標的 - 6228
# 第1547個標的 - 6229
# 第1548個標的 - 6230
# 第1549個標的 - 6231 ⚠️ YoY < 10%，跳過
# 第1550個標的 - 6232
# 第1551個標的 - 6233 ⚠️ YoY < 10%，跳過
# 第1552個標的 - 6234
# 第1553個標的 - 6235
# 第1554個標的 - 6236 ⚠️ YoY < 10%，跳過
# 第1555個標的 - 6237
# 第1556個標的 - 6238
# 第1557個標的 - 6239
# 第1558個標的 - 6240 ⚠️ YoY < 10%，跳過
# 第1559個標的 - 6241 ⚠️ YoY < 10%，跳過
# 第1560個標的 - 6242 ⚠️ YoY < 10%，跳過
# 第1561個標的 - 6243 ⚠️ YoY < 10%，跳過
# 第1562個標的 - 6244 ⚠️ YoY < 10%，跳過
# 第1563個標的 - 6245 ⚠️ YoY < 10%，跳過
# 第1564個標的 - 6246 ⚠️ YoY < 10%，跳過
# 第1565個標的 - 6247
# 第1566個標的 - 6248 ⚠️ YoY < 10%，跳過
# 第1567個標的 - 6250
# 第1568個標的 - 6251
# 第1569個標的 - 6255
# 第1570個標的 - 6257
# 第1571個標的 - 6259 ⚠️ YoY < 10%，跳過
# 第1572個標的 - 6261
# 第1573個標的 - 6263 ⚠️ YoY < 10%，跳過
# 第1574個標的 - 6264
# 第1575個標的 - 6265
# 第1576個標的 - 6266
# ✅ 6266 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第1577個標的 - 6269 ⚠️ YoY < 10%，跳過
# 第1578個標的 - 6270 ⚠️ YoY < 10%，跳過
# 第1579個標的 - 6271 ⚠️ YoY < 10%，跳過
# 第1580個標的 - 6272 ⚠️ YoY < 10%，跳過
# 第1581個標的 - 6274
# 第1582個標的 - 6275
# 第1583個標的 - 6276 ⚠️ YoY < 10%，跳過
# 第1584個標的 - 6277
# 第1585個標的 - 6278 ⚠️ YoY < 10%，跳過
# 第1586個標的 - 6279 ⚠️ YoY < 10%，跳過
# 第1587個標的 - 6280
# 第1588個標的 - 6281 ⚠️ YoY < 10%，跳過
# 第1589個標的 - 6282
# 第1590個標的 - 6283 ⚠️ YoY < 10%，跳過
# 第1591個標的 - 6284
# 第1592個標的 - 6285 ⚠️ YoY < 10%，跳過
# 第1593個標的 - 6286
# 第1594個標的 - 6288
# 第1595個標的 - 6289
# 第1596個標的 - 6290
# 第1597個標的 - 6291
# 第1598個標的 - 6292 ⚠️ YoY < 10%，跳過
# 第1599個標的 - 6294 ⚠️ YoY < 10%，跳過
# 第1600個標的 - 6298
# 第1601個標的 - 6402
# 第1602個標的 - 6404
# 第1603個標的 - 6405 ⚠️ YoY < 10%，跳過
# 第1604個標的 - 6409 ⚠️ YoY < 10%，跳過
# 第1605個標的 - 6411 ⚠️ YoY < 10%，跳過
# 第1606個標的 - 6412 ⚠️ YoY < 10%，跳過
# 第1607個標的 - 6414 ⚠️ YoY < 10%，跳過
# 第1608個標的 - 6415 ⚠️ YoY < 10%，跳過
# 第1609個標的 - 6416
# ❌ 6416 - 第-1根不符合，open 或 close 未高於上軌 ❌
# 第1610個標的 - 6417
# ✅ 6417 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第1611個標的 - 6418
# 第1612個標的 - 6419 ⚠️ YoY < 10%，跳過
# 第1613個標的 - 6422 ⚠️ 無 YoY 資料，跳過
# 第1614個標的 - 6423 ⚠️ YoY < 10%，跳過
# 第1615個標的 - 6425 ⚠️ YoY < 10%，跳過
# 第1616個標的 - 6426
# 第1617個標的 - 6431
# 第1618個標的 - 6432
# 第1619個標的 - 6435
# ❌ 6435 - 第-2根不符合，open 或 close 未高於上軌 ❌
# 第1620個標的 - 6438
# 第1621個標的 - 6441 ⚠️ YoY < 10%，跳過
# 第1622個標的 - 6442 ⚠️ YoY < 10%，跳過
# 第1623個標的 - 6443 ⚠️ YoY < 10%，跳過
# 第1624個標的 - 6446
# 第1625個標的 - 6449
# 第1626個標的 - 6451 ⚠️ YoY < 10%，跳過
# 第1627個標的 - 6452
# 第1628個標的 - 6456 ⚠️ YoY < 10%，跳過
# 第1629個標的 - 6461 ⚠️ YoY < 10%，跳過
# 第1630個標的 - 6462
# 第1631個標的 - 6464 ⚠️ YoY < 10%，跳過
# 第1632個標的 - 6465
# 第1633個標的 - 6469 ⚠️ YoY < 10%，跳過
# 第1634個標的 - 6470 ⚠️ YoY < 10%，跳過
# 第1635個標的 - 6472 ⚠️ YoY < 10%，跳過
# 第1636個標的 - 6474 ⚠️ YoY < 10%，跳過
# 第1637個標的 - 6477 ⚠️ YoY < 10%，跳過
# 第1638個標的 - 6482 ⚠️ YoY < 10%，跳過
# 第1639個標的 - 6485
# 第1640個標的 - 6486
# 第1641個標的 - 6488 ⚠️ YoY < 10%，跳過
# 第1642個標的 - 6491 ⚠️ YoY < 10%，跳過
# 第1643個標的 - 6492 ⚠️ YoY < 10%，跳過
# 第1644個標的 - 6494
# 第1645個標的 - 6496
# ❌ 6496 - 第-2根不符合，open 或 close 未高於上軌 ❌
# 第1646個標的 - 6497
# 第1647個標的 - 6498 ⚠️ YoY < 10%，跳過
# 第1648個標的 - 6499
# 第1649個標的 - 6504 ⚠️ YoY < 10%，跳過
# 第1650個標的 - 6505 ⚠️ YoY < 10%，跳過
# 第1651個標的 - 6506
# 第1652個標的 - 6508
# 第1653個標的 - 6509 ⚠️ YoY < 10%，跳過
# 第1654個標的 - 6510 ⚠️ YoY < 10%，跳過
# 第1655個標的 - 6512 ⚠️ YoY < 10%，跳過
# 第1656個標的 - 6514
# 第1657個標的 - 6515
# 第1658個標的 - 6516
# 第1659個標的 - 6517 ⚠️ YoY < 10%，跳過
# 第1660個標的 - 6523
# 第1661個標的 - 6525
# 第1662個標的 - 6526 ⚠️ YoY < 10%，跳過
# 第1663個標的 - 6527
# 第1664個標的 - 6530
# 第1665個標的 - 6531
# 第1666個標的 - 6532 ⚠️ YoY < 10%，跳過
# 第1667個標的 - 6533
# 第1668個標的 - 6534
# 第1669個標的 - 6535 ⚠️ YoY < 10%，跳過
# 第1670個標的 - 6538 ⚠️ YoY < 10%，跳過
# 第1671個標的 - 6541
# 第1672個標的 - 6542
# 第1673個標的 - 6546
# 第1674個標的 - 6547
# 第1675個標的 - 6548
# 第1676個標的 - 6550 ⚠️ YoY < 10%，跳過
# 第1677個標的 - 6552 ⚠️ YoY < 10%，跳過
# 第1678個標的 - 6554 ⚠️ 無 YoY 資料，跳過
# 第1679個標的 - 6556 ⚠️ YoY < 10%，跳過
# 第1680個標的 - 6558 ⚠️ YoY < 10%，跳過
# 第1681個標的 - 6560
# 第1682個標的 - 6561 ⚠️ YoY < 10%，跳過
# 第1683個標的 - 6568
# 第1684個標的 - 6569 ⚠️ YoY < 10%，跳過
# 第1685個標的 - 6570
# 第1686個標的 - 6573 ⚠️ YoY < 10%，跳過
# 第1687個標的 - 6574
# 第1688個標的 - 6576 ⚠️ YoY < 10%，跳過
# 第1689個標的 - 6577 ⚠️ YoY < 10%，跳過
# 第1690個標的 - 6578
# 第1691個標的 - 6579
# ✅ 6579 - 符合條件（突破 + 後續 2 根站上），加入 long_result ✅
# 第1692個標的 - 6581
# 第1693個標的 - 6582 ⚠️ YoY < 10%，跳過
# 第1694個標的 - 6584
# 第1695個標的 - 6585 ⚠️ YoY < 10%，跳過
# 第1696個標的 - 6588
# 第1697個標的 - 6589
# 第1698個標的 - 6590 ⚠️ YoY < 10%，跳過
# 第1699個標的 - 6591
# 第1700個標的 - 6592 ⚠️ YoY < 10%，跳過
# 第1701個標的 - 6593 ⚠️ YoY < 10%，跳過
# 第1702個標的 - 6594
# 第1703個標的 - 6596 ⚠️ YoY < 10%，跳過
# 第1704個標的 - 6597 ⚠️ YoY < 10%，跳過
# 第1705個標的 - 6598
# 第1706個標的 - 6603
# ✅ 6603 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第1707個標的 - 6605 ⚠️ YoY < 10%，跳過
# 第1708個標的 - 6606 ⚠️ YoY < 10%，跳過
# 第1709個標的 - 6609 ⚠️ YoY < 10%，跳過
# 第1710個標的 - 6612
# 第1711個標的 - 6613 ⚠️ YoY < 10%，跳過
# 第1712個標的 - 6614 ⚠️ YoY < 10%，跳過
# 第1713個標的 - 6615 ⚠️ YoY < 10%，跳過
# 第1714個標的 - 6616 ⚠️ YoY < 10%，跳過
# 第1715個標的 - 6617
# 第1716個標的 - 6620 ⚠️ 無 YoY 資料，跳過
# 第1717個標的 - 6624 ⚠️ YoY < 10%，跳過
# 第1718個標的 - 6625 ⚠️ YoY < 10%，跳過
# 第1719個標的 - 6629
# 第1720個標的 - 6637
# ✅ 6637 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第1721個標的 - 6640
# 第1722個標的 - 6641 ⚠️ YoY < 10%，跳過
# 第1723個標的 - 6642 ⚠️ YoY < 10%，跳過
# 第1724個標的 - 6643
# ✅ 6643 - 符合條件（突破 + 後續 2 根站上），加入 long_result ✅
# 第1725個標的 - 6645 ⚠️ YoY < 10%，跳過
# 第1726個標的 - 6649
# ❌ 6649 - 第-2根不符合，open 或 close 未高於上軌 ❌
# 第1727個標的 - 6651 ⚠️ YoY < 10%，跳過
# 第1728個標的 - 6654
# 第1729個標的 - 6655
# ❌ 6655 - 第-1根不符合，open 或 close 未高於上軌 ❌
# 第1730個標的 - 6657
# 第1731個標的 - 6658
# 第1732個標的 - 6661
# 第1733個標的 - 6662 ⚠️ YoY < 10%，跳過
# 第1734個標的 - 6664
# 第1735個標的 - 6666
# 第1736個標的 - 6667
# 第1737個標的 - 6668
# 第1738個標的 - 6669
# ❌ 6669 - 第-1根不符合，open 或 close 未高於上軌 ❌
# 第1739個標的 - 6670 ⚠️ YoY < 10%，跳過
# 第1740個標的 - 6671
# 第1741個標的 - 6672
# 第1742個標的 - 6674 ⚠️ YoY < 10%，跳過
# 第1743個標的 - 6679 ⚠️ YoY < 10%，跳過
# 第1744個標的 - 6680
# 第1745個標的 - 6683 ⚠️ YoY < 10%，跳過
# 第1746個標的 - 6684
# 第1747個標的 - 6689 ⚠️ YoY < 10%，跳過
# 第1748個標的 - 6690
# 第1749個標的 - 6691
# 第1750個標的 - 6692 ⚠️ YoY < 10%，跳過
# 第1751個標的 - 6693
# 第1752個標的 - 6695 ⚠️ YoY < 10%，跳過
# 第1753個標的 - 6697 ⚠️ YoY < 10%，跳過
# 第1754個標的 - 6698
# 第1755個標的 - 6702
# 第1756個標的 - 6703
# 第1757個標的 - 6706 ⚠️ YoY < 10%，跳過
# 第1758個標的 - 6708
# 第1759個標的 - 6712 ⚠️ YoY < 10%，跳過
# 第1760個標的 - 6715 ⚠️ YoY < 10%，跳過
# 第1761個標的 - 6716 ⚠️ YoY < 10%，跳過
# 第1762個標的 - 6719
# 第1763個標的 - 6720 ⚠️ YoY < 10%，跳過
# 第1764個標的 - 6721
# 第1765個標的 - 6725 ⚠️ 無 YoY 資料，跳過
# 第1766個標的 - 6727
# 第1767個標的 - 6728
# ✅ 6728 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第1768個標的 - 6730
# 第1769個標的 - 6732
# 第1770個標的 - 6733
# ❌ 6733 - 第-3根不符合，open 或 close 未高於上軌 ❌
# 第1771個標的 - 6735
# 第1772個標的 - 6739
# 第1773個標的 - 6741
# ❌ 6741 - 第-2根不符合，open 或 close 未高於上軌 ❌
# 第1774個標的 - 6742 ⚠️ YoY < 10%，跳過
# 第1775個標的 - 6743 ⚠️ YoY < 10%，跳過
# 第1776個標的 - 6751 ⚠️ YoY < 10%，跳過
# 第1777個標的 - 6752
# 第1778個標的 - 6753 ⚠️ YoY < 10%，跳過
# 第1779個標的 - 6754 ⚠️ YoY < 10%，跳過
# 第1780個標的 - 6756
# 第1781個標的 - 6757
# 第1782個標的 - 6761 ⚠️ YoY < 10%，跳過
# 第1783個標的 - 6762 ⚠️ YoY < 10%，跳過
# 第1784個標的 - 6763
# 第1785個標的 - 6767 ⚠️ YoY < 10%，跳過
# 第1786個標的 - 6768 ⚠️ YoY < 10%，跳過
# 第1787個標的 - 6770
# 第1788個標的 - 6771 ⚠️ YoY < 10%，跳過
# 第1789個標的 - 6776
# 第1790個標的 - 6781
# 第1791個標的 - 6782
# ❌ 6782 - 第-1根不符合，open 或 close 未高於上軌 ❌
# 第1792個標的 - 6785 ⚠️ YoY < 10%，跳過
# 第1793個標的 - 6788
# 第1794個標的 - 6789 ⚠️ YoY < 10%，跳過
# 第1795個標的 - 6790 ⚠️ YoY < 10%，跳過
# 第1796個標的 - 6791
# 第1797個標的 - 6792 ⚠️ YoY < 10%，跳過
# 第1798個標的 - 6794 ⚠️ YoY < 10%，跳過
# 第1799個標的 - 6796
# 第1800個標的 - 6799
# 第1801個標的 - 6803
# 第1802個標的 - 6804 ⚠️ YoY < 10%，跳過
# 第1803個標的 - 6805
# 第1804個標的 - 6806 ⚠️ YoY < 10%，跳過
# 第1805個標的 - 6807 ⚠️ YoY < 10%，跳過
# 第1806個標的 - 6811
# 第1807個標的 - 6821 ⚠️ YoY < 10%，跳過
# 第1808個標的 - 6823
# 第1809個標的 - 6829 ⚠️ YoY < 10%，跳過
# 第1810個標的 - 6830
# 第1811個標的 - 6831
# 第1812個標的 - 6834 ⚠️ YoY < 10%，跳過
# 第1813個標的 - 6835 ⚠️ YoY < 10%，跳過
# 第1814個標的 - 6838 ⚠️ YoY < 10%，跳過
# 第1815個標的 - 6840
# ❌ 6840 - 第-2根不符合，open 或 close 未高於上軌 ❌
# 第1816個標的 - 6841
# 第1817個標的 - 6843
# 第1818個標的 - 6844 ⚠️ YoY < 10%，跳過
# 第1819個標的 - 6846
# 第1820個標的 - 6854 ⚠️ YoY < 10%，跳過
# 第1821個標的 - 6855
# 第1822個標的 - 6856 ⚠️ YoY < 10%，跳過
# 第1823個標的 - 6859 ⚠️ YoY < 10%，跳過
# 第1824個標的 - 6861
# 第1825個標的 - 6862 ⚠️ YoY < 10%，跳過
# 第1826個標的 - 6863 ⚠️ YoY < 10%，跳過
# 第1827個標的 - 6865 ⚠️ YoY < 10%，跳過
# 第1828個標的 - 6869
# 第1829個標的 - 6870
# 第1830個標的 - 6872 ⚠️ YoY < 10%，跳過
# 第1831個標的 - 6873 ⚠️ YoY < 10%，跳過
# 第1832個標的 - 6874
# 第1833個標的 - 6875 ⚠️ YoY < 10%，跳過
# 第1834個標的 - 6877 ⚠️ YoY < 10%，跳過
# 第1835個標的 - 6881
# 第1836個標的 - 6884
# 第1837個標的 - 6885
# 第1838個標的 - 6887 ⚠️ YoY < 10%，跳過
# 第1839個標的 - 6890 ⚠️ YoY < 10%，跳過
# 第1840個標的 - 6894
# 第1841個標的 - 6895
# 第1842個標的 - 6899
# 第1843個標的 - 6901 ⚠️ YoY < 10%，跳過
# 第1844個標的 - 6902
# 第1845個標的 - 6903
# 第1846個標的 - 6904 ⚠️ YoY < 10%，跳過
# 第1847個標的 - 6906 ⚠️ YoY < 10%，跳過
# 第1848個標的 - 6909
# 第1849個標的 - 6910 ⚠️ YoY < 10%，跳過
# 第1850個標的 - 6913
# 第1851個標的 - 6914
# 第1852個標的 - 6916
# 第1853個標的 - 6918 ⚠️ YoY < 10%，跳過
# 第1854個標的 - 6919
# 第1855個標的 - 6921
# 第1856個標的 - 6922 ⚠️ YoY < 10%，跳過
# 第1857個標的 - 6923 ⚠️ YoY < 10%，跳過
# 第1858個標的 - 6924 ⚠️ YoY < 10%，跳過
# 第1859個標的 - 6925
# 第1860個標的 - 6928 ⚠️ YoY < 10%，跳過
# 第1861個標的 - 6929 ⚠️ YoY < 10%，跳過
# 第1862個標的 - 6931
# 第1863個標的 - 6933 ⚠️ YoY < 10%，跳過
# 第1864個標的 - 6936 ⚠️ YoY < 10%，跳過
# 第1865個標的 - 6937 ⚠️ YoY < 10%，跳過
# 第1866個標的 - 6944
# 第1867個標的 - 6949
# 第1868個標的 - 6951
# ❌ 6951 - 第-3根不符合，open 或 close 未高於上軌 ❌
# ✅ 6951 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第1869個標的 - 6952
# 第1870個標的 - 6953
# 第1871個標的 - 6955
# 第1872個標的 - 6957 ⚠️ YoY < 10%，跳過
# 第1873個標的 - 6958 ⚠️ YoY < 10%，跳過
# 第1874個標的 - 6962 ⚠️ YoY < 10%，跳過
# 第1875個標的 - 6965 ⚠️ YoY < 10%，跳過
# 第1876個標的 - 6967
# 第1877個標的 - 6968
# 第1878個標的 - 6969
# 第1879個標的 - 6971 ⚠️ YoY < 10%，跳過
# 第1880個標的 - 6982
# 第1881個標的 - 6988
# ✅ 6988 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第1882個標的 - 6994
# 第1883個標的 - 6996
# ✅ 6996 - 符合條件（突破 + 後續 2 根站上），加入 long_result ✅
# 第1884個標的 - 6997
# 第1885個標的 - 7402 ⚠️ YoY < 10%，跳過
# 第1886個標的 - 7547 ⚠️ YoY < 10%，跳過
# 第1887個標的 - 7556
# 第1888個標的 - 7584 ⚠️ YoY < 10%，跳過
# 第1889個標的 - 7610
# 第1890個標的 - 7631
# 第1891個標的 - 7642 ⚠️ YoY < 10%，跳過
# 第1892個標的 - 7703 ⚠️ YoY < 10%，跳過
# 第1893個標的 - 7704
# 第1894個標的 - 7705
# 第1895個標的 - 7708
# 第1896個標的 - 7709
# 第1897個標的 - 7711
# 第1898個標的 - 7712 ⚠️ YoY < 10%，跳過
# 第1899個標的 - 7713
# 第1900個標的 - 7714 ⚠️ YoY < 10%，跳過
# 第1901個標的 - 7715 ⚠️ YoY < 10%，跳過
# 第1902個標的 - 7716 ⚠️ YoY < 10%，跳過
# 第1903個標的 - 7717
# 第1904個標的 - 7718
# 第1905個標的 - 7721 ⚠️ YoY < 10%，跳過
# 第1906個標的 - 7722
# 第1907個標的 - 7723 ⚠️ YoY < 10%，跳過
# 第1908個標的 - 7728
# 第1909個標的 - 7730
# 第1910個標的 - 7732 ⚠️ YoY < 10%，跳過
# 第1911個標的 - 7734
# 第1912個標的 - 7736 ⚠️ YoY < 10%，跳過
# 第1913個標的 - 7738
# 第1914個標的 - 7740
# 第1915個標的 - 7743 ⚠️ YoY < 10%，跳過
# 第1916個標的 - 7744
# 第1917個標的 - 7747 ⚠️ YoY < 10%，跳過
# 第1918個標的 - 7749
# 第1919個標的 - 7750
# 第1920個標的 - 7751
# 第1921個標的 - 7753 ⚠️ YoY < 10%，跳過
# 第1922個標的 - 7757
# 第1923個標的 - 7765 ⚠️ YoY < 10%，跳過
# 第1924個標的 - 7767 ⚠️ YoY < 10%，跳過
# 第1925個標的 - 7769
# 第1926個標的 - 7770 ⚠️ YoY < 10%，跳過
# 第1927個標的 - 7777
# 第1928個標的 - 7780
# ✅ 7780 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第1929個標的 - 7782 ⚠️ YoY < 10%，跳過
# 第1930個標的 - 7786 ⚠️ YoY < 10%，跳過
# 第1931個標的 - 7788
# 第1932個標的 - 7791 ⚠️ YoY < 10%，跳過
# 第1933個標的 - 7799
# 第1934個標的 - 7805
# 第1935個標的 - 7810
# 第1936個標的 - 8008
# 第1937個標的 - 8011 ⚠️ YoY < 10%，跳過
# 第1938個標的 - 8016
# ✅ 8016 - 符合條件（突破 + 後續 2 根站上），加入 long_result ✅
# 第1939個標的 - 8021
# 第1940個標的 - 8024 ⚠️ YoY < 10%，跳過
# 第1941個標的 - 8027
# 第1942個標的 - 8028
# 第1943個標的 - 8032
# 第1944個標的 - 8033 ⚠️ YoY < 10%，跳過
# 第1945個標的 - 8034 ⚠️ YoY < 10%，跳過
# 第1946個標的 - 8038
# 第1947個標的 - 8039
# 第1948個標的 - 8040 ⚠️ YoY < 10%，跳過
# 第1949個標的 - 8042
# 第1950個標的 - 8043
# 第1951個標的 - 8044 ⚠️ YoY < 10%，跳過
# 第1952個標的 - 8045 ⚠️ YoY < 10%，跳過
# 第1953個標的 - 8046
# 第1954個標的 - 8047 ⚠️ YoY < 10%，跳過
# 第1955個標的 - 8048 ⚠️ YoY < 10%，跳過
# 第1956個標的 - 8049
# ✅ 8049 - 符合條件（突破 + 後續 3 根站上），加入 long_result ✅
# 第1957個標的 - 8050 ⚠️ YoY < 10%，跳過
# 第1958個標的 - 8053
# 第1959個標的 - 8054
# 第1960個標的 - 8059
# ✅ 8059 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第1961個標的 - 8064
# 第1962個標的 - 8066 ⚠️ YoY < 10%，跳過
# 第1963個標的 - 8067 ⚠️ YoY < 10%，跳過
# 第1964個標的 - 8068
# 第1965個標的 - 8069 ⚠️ YoY < 10%，跳過
# 第1966個標的 - 8070
# ✅ 8070 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第1967個標的 - 8071 ⚠️ YoY < 10%，跳過
# 第1968個標的 - 8072
# ❌ 8072 - 第-2根不符合，open 或 close 未高於上軌 ❌
# 第1969個標的 - 8074
# ✅ 8074 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第1970個標的 - 8076 ⚠️ YoY < 10%，跳過
# 第1971個標的 - 8077 ⚠️ YoY < 10%，跳過
# 第1972個標的 - 8078
# 第1973個標的 - 8079
# 第1974個標的 - 8080
# 第1975個標的 - 8081
# 第1976個標的 - 8082
# 第1977個標的 - 8083
# 第1978個標的 - 8084 ⚠️ YoY < 10%，跳過
# 第1979個標的 - 8085
# 第1980個標的 - 8086
# 第1981個標的 - 8087 ⚠️ YoY < 10%，跳過
# 第1982個標的 - 8088
# 第1983個標的 - 8089 ⚠️ YoY < 10%，跳過
# 第1984個標的 - 8091
# 第1985個標的 - 8092
# 第1986個標的 - 8093
# 第1987個標的 - 8096
# 第1988個標的 - 8097
# 第1989個標的 - 8099
# 第1990個標的 - 8101 ⚠️ YoY < 10%，跳過
# 第1991個標的 - 8102 ⚠️ YoY < 10%，跳過
# 第1992個標的 - 8103
# 第1993個標的 - 8104 ⚠️ YoY < 10%，跳過
# 第1994個標的 - 8105 ⚠️ YoY < 10%，跳過
# 第1995個標的 - 8107 ⚠️ YoY < 10%，跳過
# 第1996個標的 - 8109
# ✅ 8109 - 符合條件（突破 + 後續 3 根站上），加入 long_result ✅
# 第1997個標的 - 8110
# 第1998個標的 - 8111 ⚠️ YoY < 10%，跳過
# 第1999個標的 - 8112
# 第2000個標的 - 8114 ⚠️ YoY < 10%，跳過
# 第2001個標的 - 8121
# 第2002個標的 - 8131
# 第2003個標的 - 8147
# 第2004個標的 - 8150
# 第2005個標的 - 8155
# 第2006個標的 - 8162 ⚠️ YoY < 10%，跳過
# 第2007個標的 - 8163 ⚠️ YoY < 10%，跳過
# 第2008個標的 - 8171
# 第2009個標的 - 8176 ⚠️ YoY < 10%，跳過
# 第2010個標的 - 8182 ⚠️ YoY < 10%，跳過
# 第2011個標的 - 8183 ⚠️ YoY < 10%，跳過
# 第2012個標的 - 8199
# 第2013個標的 - 8201
# 第2014個標的 - 8210
# 第2015個標的 - 8213
# ✅ 8213 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第2016個標的 - 8215 ⚠️ YoY < 10%，跳過
# 第2017個標的 - 8222
# ✅ 8222 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第2018個標的 - 8227
# 第2019個標的 - 8234 ⚠️ YoY < 10%，跳過
# 第2020個標的 - 8240 ⚠️ YoY < 10%，跳過
# 第2021個標的 - 8249
# ✅ 8249 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第2022個標的 - 8255 ⚠️ YoY < 10%，跳過
# 第2023個標的 - 8261 ⚠️ YoY < 10%，跳過
# 第2024個標的 - 8266
# 第2025個標的 - 8271
# 第2026個標的 - 8272
# 第2027個標的 - 8277 ⚠️ YoY < 10%，跳過
# 第2028個標的 - 8279
# 第2029個標的 - 8284
# 第2030個標的 - 8287
# 第2031個標的 - 8289 ⚠️ YoY < 10%，跳過
# 第2032個標的 - 8291
# 第2033個標的 - 8299
# 第2034個標的 - 8341 ⚠️ YoY < 10%，跳過
# 第2035個標的 - 8342 ⚠️ YoY < 10%，跳過
# 第2036個標的 - 8349 ⚠️ YoY < 10%，跳過
# 第2037個標的 - 8354 ⚠️ YoY < 10%，跳過
# 第2038個標的 - 8358
# 第2039個標的 - 8367
# 第2040個標的 - 8374
# ❌ 8374 - 第-2根不符合，open 或 close 未高於上軌 ❌
# 第2041個標的 - 8383
# ✅ 8383 - 突破點為最後一根，無後續K棒可驗證，直接加入 ✅
# 第2042個標的 - 8390 ⚠️ YoY < 10%，跳過
# 第2043個標的 - 8401 ⚠️ YoY < 10%，跳過
# 第2044個標的 - 8403 ⚠️ YoY < 10%，跳過
# 第2045個標的 - 8404
# 第2046個標的 - 8406
# 第2047個標的 - 8409 ⚠️ YoY < 10%，跳過
# 第2048個標的 - 8410 ⚠️ YoY < 10%，跳過
# 第2049個標的 - 8411 ⚠️ YoY < 10%，跳過
# 第2050個標的 - 8415
# 第2051個標的 - 8416 ⚠️ YoY < 10%，跳過
# 第2052個標的 - 8418
# 第2053個標的 - 8420
# 第2054個標的 - 8421
# 第2055個標的 - 8422 ⚠️ YoY < 10%，跳過
# 第2056個標的 - 8423
# 第2057個標的 - 8424 ⚠️ YoY < 10%，跳過
# 第2058個標的 - 8426 ⚠️ YoY < 10%，跳過
# 第2059個標的 - 8427
# 第2060個標的 - 8429 ⚠️ YoY < 10%，跳過
# 第2061個標的 - 8431 ⚠️ YoY < 10%，跳過
# 第2062個標的 - 8432 ⚠️ YoY < 10%，跳過
# 第2063個標的 - 8433 ⚠️ YoY < 10%，跳過
# 第2064個標的 - 8435 ⚠️ YoY < 10%，跳過
# 第2065個標的 - 8436
# 第2066個標的 - 8437 ⚠️ YoY < 10%，跳過
# 第2067個標的 - 8438
# 第2068個標的 - 8440 ⚠️ YoY < 10%，跳過
# 第2069個標的 - 8442
# 第2070個標的 - 8443 ⚠️ YoY < 10%，跳過
# 第2071個標的 - 8444 ⚠️ YoY < 10%，跳過
# 第2072個標的 - 8446 ⚠️ YoY < 10%，跳過
# 第2073個標的 - 8450 ⚠️ YoY < 10%，跳過
# 第2074個標的 - 8454 ⚠️ YoY < 10%，跳過
# 第2075個標的 - 8455 ⚠️ YoY < 10%，跳過
# 第2076個標的 - 8462
# ✅ 8462 - 符合條件（突破 + 後續 1 根站上），加入 long_result ✅
# 第2077個標的 - 8463 ⚠️ YoY < 10%，跳過
# 第2078個標的 - 8464 ⚠️ YoY < 10%，跳過
# 第2079個標的 - 8466 ⚠️ YoY < 10%，跳過
# 第2080個標的 - 8467 ⚠️ YoY < 10%，跳過
# 第2081個標的 - 8472 ⚠️ YoY < 10%，跳過
# 第2082個標的 - 8473
# 第2083個標的 - 8476
# 第2084個標的 - 8477 ⚠️ YoY < 10%，跳過
# 第2085個標的 - 8478
# 第2086個標的 - 8480
# 第2087個標的 - 8481
# 第2088個標的 - 8482
# 第2089個標的 - 8487 ⚠️ YoY < 10%，跳過
# 第2090個標的 - 8488 ⚠️ YoY < 10%，跳過
# 第2091個標的 - 8489
# 第2092個標的 - 8497
# 第2093個標的 - 8499
# 第2094個標的 - 8705
# 第2095個標的 - 8905 ⚠️ YoY < 10%，跳過
# 第2096個標的 - 8906 ⚠️ YoY < 10%，跳過
# 第2097個標的 - 8908 ⚠️ YoY < 10%，跳過
# 第2098個標的 - 8913
# 第2099個標的 - 8916
# 第2100個標的 - 8917 ⚠️ YoY < 10%，跳過
# 第2101個標的 - 8921
# 第2102個標的 - 8923 ⚠️ YoY < 10%，跳過
# 第2103個標的 - 8924
# 第2104個標的 - 8925
# 第2105個標的 - 8926 ⚠️ YoY < 10%，跳過
# 第2106個標的 - 8927
# 第2107個標的 - 8928 ⚠️ YoY < 10%，跳過
# 第2108個標的 - 8929 ⚠️ YoY < 10%，跳過
# 第2109個標的 - 8930 ⚠️ YoY < 10%，跳過
# 第2110個標的 - 8931 ⚠️ YoY < 10%，跳過
# 第2111個標的 - 8932 ⚠️ YoY < 10%，跳過
# 第2112個標的 - 8933 ⚠️ YoY < 10%，跳過
# 第2113個標的 - 8934
# 第2114個標的 - 8935 ⚠️ YoY < 10%，跳過
# 第2115個標的 - 8936 ⚠️ YoY < 10%，跳過
# 第2116個標的 - 8937 ⚠️ YoY < 10%，跳過
# 第2117個標的 - 8938 ⚠️ YoY < 10%，跳過
# 第2118個標的 - 8940 ⚠️ YoY < 10%，跳過
# 第2119個標的 - 8941 ⚠️ YoY < 10%，跳過
# 第2120個標的 - 8942 ⚠️ YoY < 10%，跳過
# 第2121個標的 - 8996
# 第2122個標的 - 910069
# 第2123個標的 - 9101 ⚠️ 無 YoY 資料，跳過
# 第2124個標的 - 9102 ⚠️ 無 YoY 資料，跳過
# 第2125個標的 - 9103 ⚠️ 無 YoY 資料，跳過
# 第2126個標的 - 910322 ⚠️ 無 YoY 資料，跳過
# 第2127個標的 - 9104 ⚠️ 無 YoY 資料，跳過
# 第2128個標的 - 910482 ⚠️ 無 YoY 資料，跳過
# 第2129個標的 - 9105 ⚠️ YoY < 10%，跳過
# 第2130個標的 - 910579 ⚠️ 無 YoY 資料，跳過
# 第2131個標的 - 9106 ⚠️ 無 YoY 資料，跳過
# 第2132個標的 - 910708 ⚠️ 無 YoY 資料，跳過
# 第2133個標的 - 910801 ⚠️ 無 YoY 資料，跳過
# 第2134個標的 - 910861 ⚠️ 無 YoY 資料，跳過
# 第2135個標的 - 910948 ⚠️ 無 YoY 資料，跳過
# 第2136個標的 - 9110 ⚠️ 無 YoY 資料，跳過
# 第2137個標的 - 911201 ⚠️ 無 YoY 資料，跳過
# 第2138個標的 - 911602 ⚠️ 無 YoY 資料，跳過
# 第2139個標的 - 911606 ⚠️ 無 YoY 資料，跳過
# 第2140個標的 - 911608 ⚠️ 無 YoY 資料，跳過
# 第2141個標的 - 911609 ⚠️ 無 YoY 資料，跳過
# 第2142個標的 - 911610 ⚠️ 無 YoY 資料，跳過
# 第2143個標的 - 911611 ⚠️ 無 YoY 資料，跳過
# 第2144個標的 - 911612 ⚠️ 無 YoY 資料，跳過
# 第2145個標的 - 911613 ⚠️ 無 YoY 資料，跳過
# 第2146個標的 - 911616 ⚠️ 無 YoY 資料，跳過
# 第2147個標的 - 911619 ⚠️ 無 YoY 資料，跳過
# 第2148個標的 - 911622 ⚠️ 無 YoY 資料，跳過
# 第2149個標的 - 911626 ⚠️ 無 YoY 資料，跳過
# 第2150個標的 - 911868 ⚠️ 無 YoY 資料，跳過
# 第2151個標的 - 912000
# 第2152個標的 - 912398
# 第2153個標的 - 9136 ⚠️ 無 YoY 資料，跳過
# 第2154個標的 - 913889 ⚠️ 無 YoY 資料，跳過
# 第2155個標的 - 9151 ⚠️ 無 YoY 資料，跳過
# 第2156個標的 - 9157 ⚠️ 無 YoY 資料，跳過
# 第2157個標的 - 916665 ⚠️ 無 YoY 資料，跳過
# 第2158個標的 - 9188 ⚠️ 無 YoY 資料，跳過
# 第2159個標的 - 9802 ⚠️ YoY < 10%，跳過
# 第2160個標的 - 9902
# 第2161個標的 - 9904 ⚠️ YoY < 10%，跳過
# 第2162個標的 - 9905
# 第2163個標的 - 9906 ⚠️ YoY < 10%，跳過
# 第2164個標的 - 9907 ⚠️ YoY < 10%，跳過
# 第2165個標的 - 9908 ⚠️ YoY < 10%，跳過
# 第2166個標的 - 9910 ⚠️ YoY < 10%，跳過
# 第2167個標的 - 9911
# 第2168個標的 - 9912
# 第2169個標的 - 9914 ⚠️ YoY < 10%，跳過
# 第2170個標的 - 9915
# 第2171個標的 - 9917 ⚠️ YoY < 10%，跳過
# 第2172個標的 - 9918 ⚠️ YoY < 10%，跳過
# 第2173個標的 - 9919 ⚠️ YoY < 10%，跳過
# 第2174個標的 - 9921 ⚠️ YoY < 10%，跳過
# 第2175個標的 - 9922
# 第2176個標的 - 9924 ⚠️ YoY < 10%，跳過
# 第2177個標的 - 9925
# 第2178個標的 - 9926 ⚠️ YoY < 10%，跳過
# 第2179個標的 - 9927
# 第2180個標的 - 9928
# 第2181個標的 - 9929 ⚠️ YoY < 10%，跳過
# 第2182個標的 - 9930 ⚠️ YoY < 10%，跳過
# 第2183個標的 - 9931
# 第2184個標的 - 9933 ⚠️ YoY < 10%，跳過
# 第2185個標的 - 9934 ⚠️ YoY < 10%，跳過
# 第2186個標的 - 9935 ⚠️ YoY < 10%，跳過
# 第2187個標的 - 9937 ⚠️ YoY < 10%，跳過
# 第2188個標的 - 9938
# 第2189個標的 - 9939 ⚠️ YoY < 10%，跳過
# 第2190個標的 - 9940
# 第2191個標的 - 9941 ⚠️ YoY < 10%，跳過
# 第2192個標的 - 9942
# ❌ 9942 - 第-1根不符合，open 或 close 未高於上軌 ❌
# 第2193個標的 - 9943 ⚠️ YoY < 10%，跳過
# 第2194個標的 - 9944
# 第2195個標的 - 9945
# 第2196個標的 - 9946
# 第2197個標的 - 9949 ⚠️ YoY < 10%，跳過
# 第2198個標的 - 9950 ⚠️ YoY < 10%，跳過
# 第2199個標的 - 9951 ⚠️ YoY < 10%，跳過
# 第2200個標的 - 9955
# 第2201個標的 - 9958 ⚠️ YoY < 10%，跳過
# 第2202個標的 - 9960
# 第2203個標的 - 9962 ⚠️ YoY < 10%，跳過
# -----------------------------------
#              open   high    low  close    YoY  MA  STD  Upper_Band  Lower_Band
# date
# 2025-12-01  20.85  20.85  20.85  20.85  10.79 NaN  NaN         NaN         NaN
# 2025-12-02  20.85  20.90  20.85  20.90  10.79 NaN  NaN         NaN         NaN
# 2025-12-03  20.85  20.85  20.85  20.85  10.79 NaN  NaN         NaN         NaN
# 2025-12-04  20.85  20.85  20.85  20.85  10.79 NaN  NaN         NaN         NaN
# 2025-12-05  20.85  20.95  20.80  20.85  10.79 NaN  NaN         NaN         NaN
# 2025-12-08  20.90  20.90  20.80  20.85  10.79 NaN  NaN         NaN         NaN
# 2025-12-09  20.80  20.80  20.80  20.80  10.79 NaN  NaN         NaN         NaN
# 2025-12-10  20.85  20.90  20.85  20.90  10.79 NaN  NaN         NaN         NaN
# 2025-12-11    NaN    NaN    NaN    NaN  10.79 NaN  NaN         NaN         NaN
# 2025-12-12  20.70  21.00  20.70  21.00  10.79 NaN  NaN         NaN         NaN
# 2025-12-15  20.95  21.00  20.95  20.95  10.79 NaN  NaN         NaN         NaN
# 2025-12-16    NaN    NaN    NaN    NaN  10.79 NaN  NaN         NaN         NaN
# 2025-12-17  21.00  21.00  20.95  20.95  10.79 NaN  NaN         NaN         NaN
# 2025-12-18  21.25  21.25  21.00  21.00  10.79 NaN  NaN         NaN         NaN
# 2025-12-19  21.00  21.00  21.00  21.00  10.79 NaN  NaN         NaN         NaN
# 2025-12-22  21.00  21.00  21.00  21.00  10.79 NaN  NaN         NaN         NaN
# 2025-12-23  21.00  21.20  21.00  21.20  10.79 NaN  NaN         NaN         NaN
# 2025-12-24  21.00  21.30  21.00  21.30  10.79 NaN  NaN         NaN         NaN
# 2025-12-26  21.30  21.50  21.30  21.50  10.79 NaN  NaN         NaN         NaN
# 2025-12-29  21.30  21.35  21.25  21.25  10.79 NaN  NaN         NaN         NaN
# 2025-12-30  21.20  21.25  21.20  21.25  10.79 NaN  NaN         NaN         NaN
# 2025-12-31  21.20  21.45  21.05  21.45  10.79 NaN  NaN         NaN         NaN
# 2026-01-02  21.30  21.30  20.80  21.10  10.79 NaN  NaN         NaN         NaN
# 2026-01-05  21.05  21.05  21.05  21.05  10.79 NaN  NaN         NaN         NaN
# 2026-01-06  21.70  21.70  21.10  21.60  10.79 NaN  NaN         NaN         NaN
# 2026-01-07  21.55  22.20  21.50  22.15  10.79 NaN  NaN         NaN         NaN
# 2026-01-08  21.90  21.90  21.70  21.70  10.79 NaN  NaN         NaN         NaN
# 2026-01-09  21.85  21.85  21.45  21.60  10.79 NaN  NaN         NaN         NaN
#
# 一般 List: [1312, 1342, 1603, 1714, 1783, 1788, 1808, 2065, 2313, 2347, 2369, 2380, 2415, 2419, 2439, 2477, 2511, 2535, 2546, 2605, 2613, 2617, 2634, 2637, 2731, 2743, 2851, 2855, 2889, 2890, 3025, 3046, 3088, 3105, 3138, 3224, 3293, 3372, 3498, 3526, 3533, 3535, 3541, 3588, 3622, 3630, 3715, 4107, 4119, 4123, 4128, 4142, 4167, 4173, 4541, 4542, 4551, 4576, 4583, 4711, 4726, 4736, 4743, 4915, 4953, 4966, 4999, 5014, 5209, 5213, 5223, 5269, 5345, 5347, 5478, 6005, 6015, 6141, 6161, 6163, 6167, 6266, 6417, 6579, 6603, 6637, 6643, 6728, 6951, 6988, 6996, 7780, 8016, 8049, 8059, 8070, 8074, 8109, 8213, 8222, 8249, 8383, 8462]
#
# 股期 List: [1312, 2313, 2347, 2439, 2605, 2634, 2890, 3105, 3293, 3533, 4123, 4128, 4736, 4743, 5269, 5347, 6005]
